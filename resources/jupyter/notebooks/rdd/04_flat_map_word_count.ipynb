# %% [markdown]
# Flatmap() can create many other multiple elements using a single one

# %%
import re
from pyspark import SparkConf, SparkContext

# %%
conf = SparkConf().setAppName("flat_map")

# %%
sc = SparkContext(conf=conf)

# %%
lines_rdd = sc.textFile("file:///var/lib/spark/jupyter/data/book.txt")

# %% [markdown]
# Below way of doing it is not that great

# %%
# words = lines_rdd.flatMap(lambda x:x.split())

# %%
# word_count = words.countByValue()

# %% [markdown]
# Slightly better way

# %%
def parse_text(text):
    return re.compile(r'\W+', re.UNICODE).split(text.lower())

# %%
words = lines_rdd.flatMap(parse_text)

# %%
word_count = words.map(lambda x:(x,1)).reduceByKey(lambda x,y:x+y)

# %%
sorted_word = word_count.map(lambda (x,y):(y,x)).sortByKey("desc").map(lambda (x,y):(y,x))

# %%
result = sorted_word.collect()

# %%
for res in result:
    print(res[0], res[1])
# Out:
# (u'hats', 1)
# (u'desirable', 1)
# (u'four', 1)
# (u'relationships', 1)
# (u'extrapolate', 1)
# (u'adaptive', 1)
# (u'fondly', 1)
# (u'announced', 1)
# (u'force', 1)
# (u'consistent', 1)
# (u'electricians', 1)
# (u'asia', 1)
# (u'mailings', 1)
# (u'disposable', 1)
# (u'104', 1)
# (u'obtained', 1)
# (u'forum', 1)
# (u'harass', 1)
# (u'calculations', 1)
# (u'astute', 1)
# (u'criticism', 1)
# (u'psychological', 1)
# (u'conflicts', 1)
# (u'achievable', 1)
# (u'counts', 1)
# (u'landscape', 1)
# (u'catchy', 1)
# (u'hospital', 1)
# (u'strike', 1)
# (u'breathe', 1)
# (u'award', 1)
# (u'93', 1)
# (u'outdated', 1)
# (u'divorced', 1)
# (u'pursue', 1)
# (u'roof', 1)
# (u'exceptions', 1)
# (u'addictive', 1)
# (u'household', 1)
# (u'appointment', 1)
# (u'machine', 1)
# (u'hot', 1)
# (u'fudge', 1)
# (u'mouths', 1)
# (u'curiosity', 1)
# (u'chump', 1)
# (u'types', 1)
# (u'attempt', 1)
# (u'attracts', 1)
# (u'teammates', 1)
# (u'goodbye', 1)
# (u'realizing', 1)
# (u'salon', 1)
# (u'rewarded', 1)
# (u'digest', 1)
# (u'edits', 1)
# (u'401', 1)
# (u'weeks', 1)
# (u'versus', 1)
# (u'affected', 1)
# (u'prevented', 1)
# (u'unemployed', 1)
# (u'reaches', 1)
# (u'niches', 1)
# (u'reasonably', 1)
# (u'legwork', 1)
# (u'substantially', 1)
# (u'reminding', 1)
# (u'fiji', 1)
# (u'braces', 1)
# (u'newly', 1)
# (u'independence', 1)
# (u'substantiation', 1)
# (u'competes', 1)
# (u'onto', 1)
# (u'iag', 1)
# (u'characters', 1)
# (u'coding', 1)
# (u'spinning', 1)
# (u'traction', 1)
# (u'plentiful', 1)
# (u'tune', 1)
# (u'happily', 1)
# (u'20081', 1)
# (u'postcards', 1)
# (u'trek', 1)
# (u'k', 1)
# (u'hacking', 1)
# (u'sees', 1)
# (u'willingness', 1)
# (u'contents', 1)
# (u'harper', 1)
# (u'climate', 1)
# (u'zoho', 1)
# (u'oriented', 1)
# (u'absorbed', 1)
# (u'looming', 1)
# (u'plenty', 1)
# (u'exercises', 1)
# (u'zealand', 1)
# (u'mitigate', 1)
# (u'emailing', 1)
# (u'contacted', 1)
# (u'preneurs', 1)
# (u'sexist', 1)
# (u'colors', 1)
# (u'lessons', 1)
# (u'submit', 1)
# (u'png', 1)
# (u'continuity', 1)
# (u'13', 1)
# (u'preferred', 1)
# (u'cushion', 1)
# (u'deborah', 1)
# (u'shots', 1)
# (u'terminology', 1)
# (u'victim', 1)
# (u'evolving', 1)
# (u'w3', 1)
# (u'arcane', 1)
# (u'cooperation', 1)
# (u'tolerance', 1)
# (u'ulterior', 1)
# (u'360', 1)
# (u'preserve', 1)
# (u'lazy', 1)
# (u'participating', 1)
# (u'lenses', 1)
# (u'presumably', 1)
# (u'tone', 1)
# (u'guaranteed', 1)
# (u'betting', 1)
# (u'cult', 1)
# (u'conference', 1)
# (u'nicer', 1)
# (u'subside', 1)
# (u'beer', 1)
# (u'topics', 1)
# (u'stresses', 1)
# (u'relaxing', 1)
# (u'uncommon', 1)
# (u'tapping', 1)
# (u'immersive', 1)
# (u'spin', 1)
# (u'fares', 1)
# (u'applied', 1)
# (u'contingencies', 1)
# (u'employ', 1)
# (u'pessimistic', 1)
# (u'associations', 1)
# (u'seven', 1)
# (u'metropolitan', 1)
# (u'sticker', 1)
# (u'brutal', 1)
# (u'inviting', 1)
# (u'youth', 1)
# (u'insulating', 1)
# (u'scenario', 1)
# (u'menial', 1)
# (u'dada', 1)
# (u'ragged', 1)
# (u'seasonal', 1)
# (u'authorize', 1)
# (u'foreigners', 1)
# (u'grades', 1)
# (u'parks', 1)
# (u'facts', 1)
# (u'volumetric', 1)
# (u'passive', 1)
# (u'brainstorming', 1)
# (u'whatsapp', 1)
# (u'opt', 1)
# (u'moleskine', 1)
# (u'survival', 1)
# (u'progressed', 1)
# (u'conversational', 1)
# (u'indicative', 1)
# (u'advanced', 1)
# (u'desire', 1)
# (u'offices', 1)
# (u'hung', 1)
# (u'storefronts', 1)
# (u'crown', 1)
# (u'handing', 1)
# (u'dead', 1)
# (u'hassle', 1)
# (u'critique', 1)
# (u'creep', 1)
# (u'proceeding', 1)
# (u'contributing', 1)
# (u'corp', 1)
# (u'architectural', 1)
# (u'graduated', 1)
# (u'super', 1)
# (u'revisiting', 1)
# (u'chapter', 1)
# (u'browse', 1)
# (u'lacked', 1)
# (u'slightly', 1)
# (u'multiply', 1)
# (u'refined', 1)
# (u'riskier', 1)
# (u'crowd', 1)
# (u'frustrations', 1)
# (u'lowest', 1)
# (u'forever', 1)
# (u'congratulations', 1)
# (u'delegated', 1)
# (u'separated', 1)
# (u'abstract', 1)
# (u'proven', 1)
# (u'billboard', 1)
# (u'fashioned', 1)
# (u'radically', 1)
# (u'authoritative', 1)
# (u'handed', 1)
# (u'republic', 1)
# (u'dilemma', 1)
# (u'adsenseformobileapps', 1)
# (u'nuance', 1)
# (u'pivoting', 1)
# (u'entrust', 1)
# (u'acqui', 1)
# (u'younger', 1)
# (u'remarkably', 1)
# (u'devoted', 1)
# (u'obamacare', 1)
# (u'environment', 1)
# (u'promoting', 1)
# (u'oversight', 1)
# (u'fullest', 1)
# (u'oftentimes', 1)
# (u'philippines', 1)
# (u'dries', 1)
# (u'1124', 1)
# (u'rough', 1)
# (u'educate', 1)
# (u'jeopardy', 1)
# (u'suspect', 1)
# (u'boost', 1)
# (u'filled', 1)
# (u'unsure', 1)
# (u'water', 1)
# (u'healthy', 1)
# (u'merely', 1)
# (u'frankly', 1)
# (u'angry', 1)
# (u'scenarios', 1)
# (u'wondering', 1)
# (u'suggestions', 1)
# (u'fkane', 1)
# (u'fuel', 1)
# (u'everywhere', 1)
# (u'concretely', 1)
# (u'originally', 1)
# (u'hardest', 1)
# (u'immortalize', 1)
# (u'lobbying', 1)
# (u'awesome', 1)
# (u'hyphenation', 1)
# (u'viewers', 1)
# (u'monitoring', 1)
# (u'cursory', 1)
# (u'discussion', 1)
# (u'spot', 1)
# (u'membership', 1)
# (u'maritime', 1)
# (u'natural', 1)
# (u'commodity', 1)
# (u'switch', 1)
# (u'downsized', 1)
# (u'refund', 1)
# (u'unsolicited', 1)
# (u'webpage', 1)
# (u'mainly', 1)
# (u'consulting', 1)
# (u'managers', 1)
# (u'ethic', 1)
# (u'astronomers', 1)
# (u'methodology', 1)
# (u'window', 1)
# (u'decades', 1)
# (u'texas', 1)
# (u'publicize', 1)
# (u'matches', 1)
# (u'scaling', 1)
# (u'nor', 1)
# (u'fla', 1)
# (u'directories', 1)
# (u'realism', 1)
# (u'unproductive', 1)
# (u'directing', 1)
# (u'challenges', 1)
# (u'ey', 1)
# (u'entering', 1)
# (u'learnings', 1)
# (u'furthermore', 1)
# (u'replacing', 1)
# (u'seriously', 1)
# (u'imperative', 1)
# (u'incentives', 1)
# (u'advantages', 1)
# (u'obligation', 1)
# (u'spotted', 1)
# (u'combinator', 1)
# (u'municipality', 1)
# (u'proofreading', 1)
# (u'americans', 1)
# (u'vote', 1)
# (u'checked', 1)
# (u'lap', 1)
# (u'returns', 1)
# (u'draft', 1)
# (u'escort', 1)
# (u'bits', 1)
# (u'elance', 1)
# (u'eyes', 1)
# (u'appreciates', 1)
# (u'broadcast', 1)
# (u'acquirers', 1)
# (u'representing', 1)
# (u'specify', 1)
# (u'15', 1)
# (u'17', 1)
# (u'19', 1)
# (u'meticulous', 1)
# (u'questionable', 1)
# (u'afoul', 1)
# (u'pro', 1)
# (u'turned', 1)
# (u'tastes', 1)
# (u'steers', 1)
# (u'breakfast', 1)
# (u'shocked', 1)
# (u'venue', 1)
# (u'personalized', 1)
# (u'begin', 1)
# (u'multiple', 1)
# (u'capitalist', 1)
# (u'complaints', 1)
# (u'lawn', 1)
# (u'surprising', 1)
# (u'discarding', 1)
# (u'conservatively', 1)
# (u'teamed', 1)
# (u'imagined', 1)
# (u'waited', 1)
# (u'ratio', 1)
# (u'believing', 1)
# (u'sierra', 1)
# (u'copywriting', 1)
# (u'symmetrically', 1)
# (u'regarding', 1)
# (u'hinges', 1)
# (u'worries', 1)
# (u'violated', 1)
# (u'relative', 1)
# (u'asleep', 1)
# (u'calendar', 1)
# (u'surfaces', 1)
# (u'enjoys', 1)
# (u'rejected', 1)
# (u'affordable', 1)
# (u'originated', 1)
# (u'blame', 1)
# (u'awards', 1)
# (u'millionaire', 1)
# (u'nudges', 1)
# (u'pop', 1)
# (u'60', 1)
# (u'68', 1)
# (u'runaway', 1)
# (u'poll8', 1)
# (u'500', 1)
# (u'foreclosed', 1)
# (u'diligent', 1)
# (u'newspaper', 1)
# (u'shops', 1)
# (u'budgeting', 1)
# (u'tiny', 1)
# (u'struggling', 1)
# (u'retweeting', 1)
# (u'driver', 1)
# (u'barber', 1)
# (u'coordinate', 1)
# (u'grumpy', 1)
# (u'212', 1)
# (u'risking', 1)
# (u'cease', 1)
# (u'angel', 1)
# (u'speed', 1)
# (u'incurring', 1)
# (u'shying', 1)
# (u'stagnant', 1)
# (u'disproportionate', 1)
# (u'starving', 1)
# (u'discontinue', 1)
# (u'admitting', 1)
# (u'venues', 1)
# (u'mom', 1)
# (u'fortune', 1)
# (u'sanity', 1)
# (u'burdens', 1)
# (u'crafted', 1)
# (u'helpcenter', 1)
# (u'bizarre', 1)
# (u'frees', 1)
# (u'provides', 1)
# (u'assembly', 1)
# (u'equivalent', 1)
# (u'notable', 1)
# (u'coached', 1)
# (u'regulations', 1)
# (u'stone', 1)
# (u'fein', 1)
# (u'pockets', 1)
# (u'road', 1)
# (u'outlook', 1)
# (u'burning', 1)
# (u'shrinking', 1)
# (u'relocation', 1)
# (u'deadlines', 1)
# (u'slowly', 1)
# (u'assumes', 1)
# (u'beginners', 1)
# (u'iduskbn0e721m20140527', 1)
# (u'e', 1)
# (u'rush', 1)
# (u'embedded', 1)
# (u'wardrobe', 1)
# (u'trading', 1)
# (u'deep', 1)
# (u'file', 1)
# (u'loyal', 1)
# (u'2006', 1)
# (u'thousand', 1)
# (u'gaining', 1)
# (u'congress', 1)
# (u'revolve', 1)
# (u'openforum', 1)
# (u'fraudulent', 1)
# (u'u', 1)
# (u'overseas', 1)
# (u'founded', 1)
# (u'talks', 1)
# (u'alt', 1)
# (u'religious', 1)
# (u'tgeonetta', 1)
# (u'laid', 1)
# (u'batched', 1)
# (u'solicit', 1)
# (u'presentation', 1)
# (u'norm', 1)
# (u'fax', 1)
# (u'straightforward', 1)
# (u'ramen', 1)
# (u'enjoyable', 1)
# (u'cable', 1)
# (u'laying', 1)
# (u'tender', 1)
# (u'penalties', 1)
# (u'maximizes', 1)
# (u'snippets', 1)
# (u'intimately', 1)
# (u'imported', 1)
# (u'paralegal', 1)
# (u'entrepreneurial', 1)
# (u'succinct', 1)
# (u'seasick', 1)
# (u'editorial', 1)
# (u'component', 1)
# (u'answers', 1)
# (u'hopelessness', 1)
# (u'introductory', 1)
# (u'skepticism', 1)
# (u'sticking', 1)
# (u'dire', 1)
# (u'partnering', 1)
# (u'screens', 1)
# (u'analyzing', 1)
# (u'factoring', 1)
# (u'objectives', 1)
# (u'kick', 1)
# (u'door', 1)
# (u'landed', 1)
# (u'encouragement', 1)
# (u'broke', 1)
# (u'helped', 1)
# (u'none', 1)
# (u'aspx', 1)
# (u'vr', 1)
# (u'nine', 1)
# (u'abandon', 1)
# (u'specialized', 1)
# (u'beautiful', 1)
# (u'scam', 1)
# (u'impacts', 1)
# (u'lives', 1)
# (u'dress', 1)
# (u'chores', 1)
# (u'xxxx', 1)
# (u'drained', 1)
# (u'css', 1)
# (u'emulate', 1)
# (u'tries', 1)
# (u'startlingly', 1)
# (u'cults', 1)
# (u'quoted', 1)
# (u'supervision', 1)
# (u'dream', 1)
# (u'september', 1)
# (u'proverbial', 1)
# (u'inquiries', 1)
# (u'romance', 1)
# (u'susceptible', 1)
# (u'28', 1)
# (u'late', 1)
# (u'crawls', 1)
# (u'fool', 1)
# (u'hurting', 1)
# (u'demographics', 1)
# (u'association', 1)
# (u'restrict', 1)
# (u'fairs', 1)
# (u'repeating', 1)
# (u'sketches', 1)
# (u'status', 1)
# (u'accelerator', 1)
# (u'generation', 1)
# (u'marketplaces', 1)
# (u'caters', 1)
# (u'wondered', 1)
# (u'print', 1)
# (u'pleasant', 1)
# (u'members', 1)
# (u'driven', 1)
# (u'conducted', 1)
# (u'contingency', 1)
# (u'feet', 1)
# (u'interact', 1)
# (u'moderately', 1)
# (u'unimaginably', 1)
# (u'mainstay', 1)
# (u'segue', 1)
# (u'passed', 1)
# (u'mentality', 1)
# (u'immediate', 1)
# (u'convinced', 1)
# (u'reliever', 1)
# (u'critically', 1)
# (u'anticipate', 1)
# (u'outrageous', 1)
# (u'marriage', 1)
# (u'helpareporter', 1)
# (u'uncomfortable', 1)
# (u'boilerplate', 1)
# (u'centered', 1)
# (u'signup', 1)
# (u'hires', 1)
# (u'unceremoniously', 1)
# (u'react', 1)
# (u'negotiating', 1)
# (u'achievement', 1)
# (u'caching', 1)
# (u'particularly', 1)
# (u'indicator', 1)
# (u'distributed', 1)
# (u'dry', 1)
# (u'theft', 1)
# (u'merchandise', 1)
# (u'catches', 1)
# (u'bars', 1)
# (u'dump', 1)
# (u'achieves', 1)
# (u'bare', 1)
# (u'materially', 1)
# (u'preparation', 1)
# (u'expert', 1)
# (u'years2', 1)
# (u'please', 1)
# (u'libraries', 1)
# (u'silly', 1)
# (u'burned', 1)
# (u'gathered', 1)
# (u'blurb', 1)
# (u'europe', 1)
# (u'refills', 1)
# (u'notoriously', 1)
# (u'respondents', 1)
# (u'invisible', 1)
# (u'treated', 1)
# (u'bryc', 1)
# (u'bots', 1)
# (u'load', 1)
# (u'liked', 1)
# (u'separation', 1)
# (u'smashing', 1)
# (u'capabilities', 1)
# (u'shutdown', 1)
# (u'volunteered', 1)
# (u'hitting', 1)
# (u'proprietor', 1)
# (u'contained', 1)
# (u'collected', 1)
# (u'firm', 1)
# (u'compromises', 1)
# (u'gas', 1)
# (u'awake', 1)
# (u'uncertain', 1)
# (u'ctr', 1)
# (u'replaced', 1)
# (u'overlooked', 1)
# (u'binding', 1)
# (u'owes', 1)
# (u'uniloc', 1)
# (u'advise', 1)
# (u'conflict', 1)
# (u'flows', 1)
# (u'aggregate', 1)
# (u'organically', 1)
# (u'withdraw', 1)
# (u'y', 1)
# (u'scouring', 1)
# (u'listening', 1)
# (u'abbreviation', 1)
# (u'vigilant', 1)
# (u'unto', 1)
# (u'informal', 1)
# (u'desist', 1)
# (u'complaint', 1)
# (u'spins', 1)
# (u'saddled', 1)
# (u'absolutely', 1)
# (u'audience', 1)
# (u'connecting', 1)
# (u'continuing', 1)
# (u'deliverables', 1)
# (u'lasts', 1)
# (u'unused', 1)
# (u'certificate', 1)
# (u'completing', 1)
# (u'germany', 1)
# (u'block', 1)
# (u'retailer', 1)
# (u'span', 1)
# (u'arcade', 1)
# (u'measured', 1)
# (u'opens', 1)
# (u'graciously', 1)
# (u'registered', 1)
# (u'hopes', 1)
# (u'role', 1)
# (u'doubling', 1)
# (u'mature', 1)
# (u'continuously', 1)
# (u'consumed', 1)
# (u'convey', 1)
# (u'mindful', 1)
# (u'electrical', 1)
# (u'department', 1)
# (u'dashes', 1)
# (u'calculating', 1)
# (u'happier', 1)
# (u'backed', 1)
# (u'walked', 1)
# (u'attaining', 1)
# (u'psyche', 1)
# (u'brochure', 1)
# (u'rewarding', 1)
# (u'implicitly', 1)
# (u'engineered', 1)
# (u'continued', 1)
# (u'magic', 1)
# (u'prototyped', 1)
# (u'gauge', 1)
# (u'depression', 1)
# (u'plays', 1)
# (u'cell', 1)
# (u'concisely', 1)
# (u'exercise', 1)
# (u'indignities', 1)
# (u'communicate', 1)
# (u'gloat', 1)
# (u'securing', 1)
# (u'weekends', 1)
# (u'composed', 1)
# (u'motor', 1)
# (u'tap', 1)
# (u'canada', 1)
# (u'cloud', 1)
# (u'confidence', 1)
# (u'usa', 1)
# (u'remains', 1)
# (u'congratulated', 1)
# (u'subsidized', 1)
# (u'reflects', 1)
# (u'dentists', 1)
# (u'inclined', 1)
# (u'testified', 1)
# (u'arranging', 1)
# (u'billed', 1)
# (u'requirments', 1)
# (u'educational', 1)
# (u'friendlier', 1)
# (u'delay', 1)
# (u'pair', 1)
# (u'panic', 1)
# (u'attend', 1)
# (u'realized', 1)
# (u'chasing', 1)
# (u'newsworthy', 1)
# (u'bing', 1)
# (u'lines', 1)
# (u'chief', 1)
# (u'unsolved', 1)
# (u'closely', 1)
# (u'advertorial', 1)
# (u'directx', 1)
# (u'varies', 1)
# (u'degrees', 1)
# (u'dad', 1)
# (u'designs', 1)
# (u'kiss', 1)
# (u'accompanies', 1)
# (u'subset', 1)
# (u'studios', 1)
# (u'static', 1)
# (u'82', 1)
# (u'programmer', 1)
# (u'salesman', 1)
# (u'special', 1)
# (u'category', 1)
# (u'defend', 1)
# (u'unprepared', 1)
# (u'electronics', 1)
# (u'immersed', 1)
# (u'reacts', 1)
# (u'payroll', 1)
# (u'approaches', 1)
# (u'collection', 1)
# (u'thrust', 1)
# (u'austin', 1)
# (u'powerful', 1)
# (u'date', 1)
# (u'instill', 1)
# (u'bears', 1)
# (u'durable', 1)
# (u'locale', 1)
# (u'attack', 1)
# (u'behaved', 1)
# (u'painful', 1)
# (u'accompany', 1)
# (u'stars', 1)
# (u'completed', 1)
# (u'unsubscribe', 1)
# (u'detection', 1)
# (u'colleagues', 1)
# (u'correlate', 1)
# (u'appealing', 1)
# (u'w9', 1)
# (u'agenda', 1)
# (u'combat', 1)
# (u'flipside', 1)
# (u'aws', 1)
# (u'eight', 1)
# (u'device', 1)
# (u'volume', 1)
# (u'upset', 1)
# (u'brought', 1)
# (u'painting', 1)
# (u'deviation', 1)
# (u'chances', 1)
# (u'agreed', 1)
# (u'textual', 1)
# (u'hopeful', 1)
# (u'regularly', 1)
# (u'doubting', 1)
# (u'overall', 1)
# (u'words', 1)
# (u'dodgy', 1)
# (u'proprietorship', 1)
# (u'grab', 1)
# (u'knowing', 1)
# (u'requirement', 1)
# (u'exists', 1)
# (u'frame', 1)
# (u'reinforce', 1)
# (u'asks', 1)
# (u'checkups', 1)
# (u'identification', 1)
# (u'correctly', 1)
# (u'tens', 1)
# (u'complement', 1)
# (u'perfect', 1)
# (u'faceless', 1)
# (u'tricky', 1)
# (u'optional', 1)
# (u'hits', 1)
# (u'limits', 1)
# (u'ramp', 1)
# (u'admit', 1)
# (u'expand', 1)
# (u'fostering', 1)
# (u'environments', 1)
# (u'packaging', 1)
# (u'beach', 1)
# (u'basing', 1)
# (u'recurring', 1)
# (u'inbound', 1)
# (u'overwhelmingly', 1)
# (u'commuted', 1)
# (u'finished', 1)
# (u'survey', 1)
# (u'examine', 1)
# (u'stunning', 1)
# (u'promoted', 1)
# (u'revisited', 1)
# (u'frustrating', 1)
# (u'respected', 1)
# (u'draining', 1)
# (u'audiences', 1)
# (u'unity', 1)
# (u'inch', 1)
# (u'tighten', 1)
# (u'tactful', 1)
# (u'beast', 1)
# (u'identity', 1)
# (u'adapted', 1)
# (u'builder', 1)
# (u'insurmountably', 1)
# (u'diversify', 1)
# (u'newest', 1)
# (u'domestic', 1)
# (u'arriving', 1)
# (u'tough', 1)
# (u'happiness', 1)
# (u'generous', 1)
# (u'recommending', 1)
# (u'acted', 1)
# (u'homework', 1)
# (u'tests', 1)
# (u'myth', 1)
# (u'recharging', 1)
# (u'journalism', 1)
# (u'foreseeable', 1)
# (u'scared', 1)
# (u'motive', 1)
# (u'star', 1)
# (u'liking', 1)
# (u'sponsoring', 1)
# (u'mined', 1)
# (u'penalize', 1)
# (u'expansion', 1)
# (u'host', 1)
# (u'bundle', 1)
# (u'instinct', 1)
# (u'marketable', 1)
# (u'cropping', 1)
# (u'column', 1)
# (u'stamp', 1)
# (u'unidirectional', 1)
# (u'equally', 1)
# (u'smarts', 1)
# (u'h2', 1)
# (u'washington', 1)
# (u'billions', 1)
# (u'assess', 1)
# (u'guard', 1)
# (u'promise', 1)
# (u'national', 1)
# (u'secret', 1)
# (u'alexa', 1)
# (u'brand', 1)
# (u'delivery', 1)
# (u'delivers', 1)
# (u'variations', 1)
# (u'distract', 1)
# (u'excitement', 1)
# (u'tricks', 1)
# (u'dots', 1)
# (u'replying', 1)
# (u'generating', 1)
# (u'highlighted', 1)
# (u'directors', 1)
# (u'troll', 1)
# (u'junk', 1)
# (u'incurred', 1)
# (u'extort', 1)
# (u'rule', 1)
# (u'determination', 1)
# (u'transitions', 1)
# (u'similarity', 1)
# (u'ridiculous', 1)
# (u'violate', 1)
# (u'crises', 1)
# (u'swat', 1)
# (u'spec', 1)
# (u'saves', 1)
# (u'unsold', 1)
# (u'lecture', 1)
# (u'unrelated', 1)
# (u'heading', 1)
# (u'whirlwind', 1)
# (u'errors', 1)
# (u'selected', 1)
# (u'conjure', 1)
# (u'specialist', 1)
# (u'pursuit', 1)
# (u'cardboard', 1)
# (u'adopt', 1)
# (u'vacations', 1)
# (u'secure', 1)
# (u'visualization', 1)
# (u'stern', 1)
# (u'cheating', 1)
# (u'assed', 1)
# (u'appeasing', 1)
# (u'motivate', 1)
# (u'bleed', 1)
# (u'inflammatory', 1)
# (u'tenacity', 1)
# (u'yahoo', 1)
# (u'warm', 1)
# (u'excellent', 1)
# (u'hold', 1)
# (u'blocking', 1)
# (u'phrases', 1)
# (u'preserving', 1)
# (u'indicates', 1)
# (u'reviewing', 1)
# (u'returning', 1)
# (u'damage', 1)
# (u'pizza', 1)
# (u'badly', 1)
# (u'rise', 1)
# (u'president', 1)
# (u'law', 1)
# (u'retail', 1)
# (u'1000', 1)
# (u'restriction', 1)
# (u'expects', 1)
# (u'frequency', 1)
# (u'manageable', 1)
# (u'production', 1)
# (u'differently', 1)
# (u'persist', 1)
# (u'silver', 1)
# (u'represents', 1)
# (u'logs', 1)
# (u'hosted', 1)
# (u'daniel', 1)
# (u'reader', 1)
# (u'surprise', 1)
# (u'linear', 1)
# (u'cornerstone', 1)
# (u'signature', 1)
# (u'hearing', 1)
# (u'timothy', 1)
# (u'rated', 1)
# (u'similarly', 1)
# (u'engagement', 1)
# (u'toolset', 1)
# (u'legs', 1)
# (u'december', 1)
# (u'distance', 1)
# (u'older', 1)
# (u'classes', 1)
# (u'feeling', 1)
# (u'bridge', 1)
# (u'boston', 1)
# (u'extorting', 1)
# (u'concrete', 1)
# (u'convenient', 1)
# (u'upholding', 1)
# (u'do7', 1)
# (u'committing', 1)
# (u'memorabilia', 1)
# (u'iterate', 1)
# (u'observation', 1)
# (u'pinterest', 1)
# (u'paragraphs', 1)
# (u'possesses', 1)
# (u'notion', 1)
# (u'reserve', 1)
# (u'ending', 1)
# (u'compensate', 1)
# (u'cheaply', 1)
# (u'availability', 1)
# (u'discretionary', 1)
# (u'pursuing', 1)
# (u'air', 1)
# (u'de', 1)
# (u'14', 1)
# (u'increasing', 1)
# (u'twice', 1)
# (u'architecture', 1)
# (u'ethical', 1)
# (u'personas', 1)
# (u'noodles', 1)
# (u'07', 1)
# (u'continually', 1)
# (u'discovers', 1)
# (u'drawn', 1)
# (u'wireframes', 1)
# (u'pirate', 1)
# (u'institution', 1)
# (u'distinction', 1)
# (u'asked', 1)
# (u'publicizing', 1)
# (u'affiliated', 1)
# (u'loaded', 1)
# (u'flexible', 1)
# (u'threw', 1)
# (u'child', 1)
# (u'aviation', 1)
# (u'naval', 1)
# (u'commerce', 1)
# (u'originate', 1)
# (u'brainstorm', 1)
# (u'rationally', 1)
# (u'teachers', 1)
# (u'applies', 1)
# (u'aid', 1)
# (u'ageist', 1)
# (u'overstated', 1)
# (u'linked', 1)
# (u'harmony', 1)
# (u'incorrectly', 1)
# (u'filtered', 1)
# (u'tricking', 1)
# (u'symmetrical', 1)
# (u'investments', 1)
# (u'cycle', 1)
# (u'prioritize', 1)
# (u'failing', 1)
# (u'800', 1)
# (u'wasteful', 1)
# (u'distribute', 1)
# (u'thanks', 1)
# (u'jose', 1)
# (u'designers', 1)
# (u'advancement', 1)
# (u'concerns', 1)
# (u'metaphorical', 1)
# (u'referral', 1)
# (u'officer', 1)
# (u'arbitrary', 1)
# (u'notorious', 1)
# (u'familiarizing', 1)
# (u'born', 1)
# (u'repelling', 1)
# (u'congratulate', 1)
# (u'companions', 1)
# (u'trademarked', 1)
# (u'bold', 1)
# (u'subscriptions', 1)
# (u'dropped', 1)
# (u'constructive', 1)
# (u'memorable', 1)
# (u'permitted', 1)
# (u'drafted', 1)
# (u'restate', 1)
# (u'publishing', 1)
# (u'entrepreneur', 1)
# (u'accomplishments', 1)
# (u'chime', 1)
# (u'stumble', 1)
# (u'east', 1)
# (u'amazingly', 1)
# (u'manufacturers', 1)
# (u'sustained', 1)
# (u'builds', 1)
# (u'ruined', 1)
# (u'lays', 1)
# (u'pricing', 1)
# (u'150', 1)
# (u'trip', 1)
# (u'newsletter', 1)
# (u'alerts', 1)
# (u'tim', 1)
# (u'trips', 1)
# (u'juices', 1)
# (u'welcome', 1)
# (u'fell', 1)
# (u'hurt', 1)
# (u'derail', 1)
# (u'happening', 1)
# (u'glass', 1)
# (u'withhold', 1)
# (u'vietnam', 1)
# (u'serious', 1)
# (u'mile', 1)
# (u'burdened', 1)
# (u'row', 1)
# (u'technique', 1)
# (u'passage', 1)
# (u'answered', 1)
# (u'dartmouth', 1)
# (u'billionaire', 1)
# (u'innovation', 1)
# (u'wallets', 1)
# (u'fatigued', 1)
# (u'entries', 1)
# (u'impressive', 1)
# (u'kits', 1)
# (u'added', 1)
# (u'attracting', 1)
# (u'fearing', 1)
# (u'undeliverable', 1)
# (u'brookings', 1)
# (u'commensurate', 1)
# (u'collateral', 1)
# (u'shift', 1)
# (u'ineffective', 1)
# (u'reis', 1)
# (u'confidentiality', 1)
# (u'dangle', 1)
# (u'explicitly', 1)
# (u'scope', 1)
# (u'organizations', 1)
# (u'defeats', 1)
# (u'cat', 1)
# (u'caf', 1)
# (u'heart', 1)
# (u'expanding', 1)
# (u'contradicts', 1)
# (u'exclude', 1)
# (u'bankrupt', 1)
# (u'watching', 1)
# (u'sudden', 1)
# (u'endorsement', 1)
# (u'optimal', 1)
# (u'insider11', 1)
# (u'maintainable', 1)
# (u'max', 1)
# (u'fueled', 1)
# (u'man', 1)
# (u'inform', 1)
# (u'tall', 1)
# (u'legitimate', 1)
# (u'serving', 1)
# (u'denial', 1)
# (u'acknowledge', 1)
# (u'reacting', 1)
# (u'unsubscribing', 1)
# (u'listing', 1)
# (u'smarter', 1)
# (u'refines', 1)
# (u'qualified', 1)
# (u'playbook', 1)
# (u'hall', 1)
# (u'47', 1)
# (u'85', 1)
# (u'moneybuilder', 1)
# (u'square', 1)
# (u'scheme', 1)
# (u'catching', 1)
# (u'sponsor', 1)
# (u'medication', 1)
# (u'opened', 1)
# (u'patenting', 1)
# (u'inaction', 1)
# (u'existed', 1)
# (u'rebel', 1)
# (u'quits', 1)
# (u'alibaba', 1)
# (u'advance', 1)
# (u'cycles', 1)
# (u'drove', 1)
# (u'officials', 1)
# (u'benefits12', 1)
# (u'terrifying', 1)
# (u'legally', 1)
# (u'cup', 1)
# (u'outreach', 1)
# (u'continuous', 1)
# (u'released', 1)
# (u'population', 1)
# (u'12', 1)
# (u'18', 1)
# (u'summary', 1)
# (u'transferred', 1)
# (u'r', 1)
# (u'fruits', 1)
# (u'proofread', 1)
# (u'russia', 1)
# (u'published', 1)
# (u'documentation', 1)
# (u'san', 1)
# (u'yoast', 1)
# (u'diligence', 1)
# (u'plunge', 1)
# (u'repeatedly', 1)
# (u'opposite', 1)
# (u'supporting', 1)
# (u'proud', 1)
# (u'quantity', 1)
# (u'laureate', 1)
# (u'filed', 1)
# (u'corner', 1)
# (u'upgrade', 1)
# (u'finalized', 1)
# (u'nearly', 1)
# (u'secondary', 1)
# (u'reveal', 1)
# (u'artist', 1)
# (u'luxuries', 1)
# (u'miles', 1)
# (u'communicated', 1)
# (u'ignored', 1)
# (u'concert', 1)
# (u'burst', 1)
# (u'signs', 1)
# (u'parking', 1)
# (u'violates', 1)
# (u'wonder', 1)
# (u'receipt', 1)
# (u'subsequent', 1)
# (u'skyscraper', 1)
# (u'perpetuity', 1)
# (u'multiplied', 1)
# (u'replacement', 1)
# (u'reaction', 1)
# (u'talented', 1)
# (u'tuck', 1)
# (u'trades', 1)
# (u'landscaper', 1)
# (u'delete', 1)
# (u'nearby', 1)
# (u'afterwards', 1)
# (u'mails', 1)
# (u'65', 1)
# (u'graphics', 1)
# (u'cares', 1)
# (u'brainwashing', 1)
# (u'judging', 1)
# (u'squatters', 1)
# (u'formed', 1)
# (u'personalization', 1)
# (u'docs', 1)
# (u'cast', 1)
# (u'transactions', 1)
# (u'telephone', 1)
# (u'quiet', 1)
# (u'harsh', 1)
# (u'html', 1)
# (u'buys', 1)
# (u'constructed', 1)
# (u'booths', 1)
# (u'gamed', 1)
# (u'foam', 1)
# (u'intended', 1)
# (u'undefined', 1)
# (u'floor', 1)
# (u'extensible', 1)
# (u'relied', 1)
# (u'justify', 1)
# (u'gates', 1)
# (u'outdoor', 1)
# (u'weekly', 1)
# (u'presumption', 1)
# (u'desktop', 1)
# (u'disappearance', 1)
# (u'disrupted', 1)
# (u'vague', 1)
# (u'furniture', 1)
# (u'server', 1)
# (u'fully', 1)
# (u'passionate', 1)
# (u'energetic', 1)
# (u'dimensions', 1)
# (u'manning', 1)
# (u'overly', 1)
# (u'conservative', 1)
# (u'dealership', 1)
# (u'scientific', 1)
# (u'manufactured', 1)
# (u'flyers', 1)
# (u'tuition', 1)
# (u'credits', 1)
# (u'manufacturer', 1)
# (u'fringe', 1)
# (u'journey', 1)
# (u'provisional', 1)
# (u'freeing', 1)
# (u'unbounded', 1)
# (u'inbox', 1)
# (u'dreaming', 1)
# (u'pirates', 1)
# (u'alleged', 1)
# (u'recommends', 1)
# (u'promote', 1)
# (u'pull', 1)
# (u'artisans', 1)
# (u'blinks', 1)
# (u'hobbies', 1)
# (u'lifetime', 1)
# (u'personnel', 1)
# (u'nasa', 1)
# (u'gambling', 1)
# (u'forcing', 1)
# (u'intention', 1)
# (u'org', 1)
# (u'dies', 1)
# (u'massachusetts', 1)
# (u'prudent', 1)
# (u'2009', 1)
# (u'strings', 1)
# (u'splitting', 1)
# (u'sunk', 1)
# (u'children', 1)
# (u'lining', 1)
# (u'realities', 1)
# (u'preserved', 1)
# (u'minded', 1)
# (u'worded', 1)
# (u'random', 1)
# (u'pesky', 1)
# (u'manages', 1)
# (u'bench', 1)
# (u'employing', 1)
# (u'portable', 1)
# (u'promotes', 1)
# (u'returned', 1)
# (u'clock', 1)
# (u'deeply', 1)
# (u'caffeine', 1)
# (u'recharge', 1)
# (u'ranged', 1)
# (u'settings', 1)
# (u'compressed', 1)
# (u'beachside', 1)
# (u'b2b', 1)
# (u'neomek', 1)
# (u'unproven', 1)
# (u'houses', 1)
# (u'losses', 1)
# (u'handful', 1)
# (u'mentions', 1)
# (u'via', 1)
# (u'requiring', 1)
# (u'0', 1)
# (u'comparing', 1)
# (u'splash', 1)
# (u'injury', 1)
# (u'achieving', 1)
# (u'stylistic', 1)
# (u'dykstra', 1)
# (u'salesforce', 1)
# (u'depleting', 1)
# (u'strategies', 1)
# (u'male', 1)
# (u'history', 1)
# (u'purchases', 1)
# (u'phrase', 1)
# (u'archive', 1)
# (u'occasionally', 1)
# (u'lakes', 1)
# (u'sneak', 1)
# (u'questioning', 1)
# (u'disable', 1)
# (u'prospecting', 1)
# (u'tweeting', 1)
# (u'bugs', 1)
# (u'crafts', 1)
# (u'pleasure', 1)
# (u'geographic', 1)
# (u'playing', 1)
# (u'oh', 1)
# (u'committed', 1)
# (u'hell', 1)
# (u'alter', 1)
# (u'landscapers', 1)
# (u'deteriorates', 1)
# (u'habits', 1)
# (u'cleaners', 1)
# (u'spam13', 1)
# (u'tahiti', 1)
# (u'dominates', 1)
# (u'foolproof', 1)
# (u'surrounded', 1)
# (u'occurs', 1)
# (u'offsets', 1)
# (u'dealt', 1)
# (u'difficulty', 1)
# (u'needing', 1)
# (u'consultations', 1)
# (u'distasteful', 1)
# (u'unexpected', 1)
# (u'regret', 1)
# (u'powerless', 1)
# (u'wonderful', 1)
# (u'finances', 1)
# (u'headache', 1)
# (u'interviewed', 1)
# (u'differentiate', 1)
# (u'businessinsider', 1)
# (u'grew', 1)
# (u'determined', 1)
# (u'deciding', 1)
# (u'derivative', 1)
# (u'scammer', 1)
# (u'substantial', 1)
# (u'depleted', 1)
# (u'timeframe', 1)
# (u'paths', 1)
# (u'cave', 1)
# (u'internal', 1)
# (u'quote', 1)
# (u'hired', 1)
# (u'70', 1)
# (u'accepting', 1)
# (u'approved', 1)
# (u'weigh', 1)
# (u'joining', 1)
# (u'cdc', 1)
# (u'tenet', 1)
# (u'entity', 1)
# (u'occupation', 1)
# (u'saturate', 1)
# (u'simulating', 1)
# (u'esthetically', 1)
# (u'heavily', 1)
# (u'paranoia', 1)
# (u'b', 1)
# (u'distraction', 1)
# (u'banking', 1)
# (u'refilled', 1)
# (u'restaurants', 1)
# (u'intelligence', 1)
# (u'mantra', 1)
# (u'angie', 1)
# (u'repairs', 1)
# (u'visiting', 1)
# (u'movie', 1)
# (u'tolls', 1)
# (u'lowered', 1)
# (u'solo', 1)
# (u'dividends', 1)
# (u'misunderstandings', 1)
# (u'mailbox', 1)
# (u'succeed', 1)
# (u'depicts', 1)
# (u'reply', 1)
# (u'consume', 1)
# (u'supply', 1)
# (u'belt', 1)
# (u'roofing', 1)
# (u'cheapest', 1)
# (u'overlook', 1)
# (u'describes', 1)
# (u'mindset', 1)
# (u'rendering', 1)
# (u'treatment', 1)
# (u'stolen', 1)
# (u'outperforms', 1)
# (u'batch', 1)
# (u'evaluates', 1)
# (u'ducks', 1)
# (u'attach', 1)
# (u'shirt', 1)
# (u'spammy', 1)
# (u'years3', 1)
# (u'hallway', 1)
# (u'ratings', 1)
# (u'robust', 1)
# (u'retention', 1)
# (u'suspicious', 1)
# (u'control10', 1)
# (u'apple', 1)
# (u'skillset', 1)
# (u'surprises', 1)
# (u'alternate', 1)
# (u'guarantees', 1)
# (u'instructors', 1)
# (u'1099', 1)
# (u'helpful', 1)
# (u'sorting', 1)
# (u'shaped', 1)
# (u'admittedly', 1)
# (u'translates', 1)
# (u'essential', 1)
# (u'understood', 1)
# (u'accomplishment', 1)
# (u'delivered', 1)
# (u'proficient', 1)
# (u'tends', 1)
# (u'prod', 1)
# (u'anecdotes', 1)
# (u'performed', 1)
# (u'dictates', 1)
# (u'obscured', 1)
# (u'god', 1)
# (u'deductibles', 1)
# (u'deserves', 1)
# (u'complimentary', 1)
# (u'seeing', 1)
# (u'framed', 1)
# (u'nobel', 1)
# (u'placing', 1)
# (u'custom', 1)
# (u'suit', 1)
# (u'himself', 1)
# (u'w3tc', 1)
# (u'specialty', 1)
# (u'gallup', 1)
# (u'cram', 1)
# (u'subsidiary', 1)
# (u'requesting', 1)
# (u'aversion', 1)
# (u'highlight', 1)
# (u'popularity', 1)
# (u'warning', 1)
# (u'codes', 1)
# (u'fixing', 1)
# (u'deviate', 1)
# (u'outsourced', 1)
# (u'gross', 1)
# (u'techcrunch', 1)
# (u'outs', 1)
# (u'formal', 1)
# (u'aggregated', 1)
# (u'tradeoff', 1)
# (u'summit', 1)
# (u'presenting', 1)
# (u'tweeted', 1)
# (u'centers', 1)
# (u'disposal', 1)
# (u'critical', 1)
# (u'stable', 1)
# (u'weather', 1)
# (u'suite', 1)
# (u'friendly', 1)
# (u'virtuous', 1)
# (u'retire', 1)
# (u'valued', 1)
# (u'gender', 1)
# (u'shock', 1)
# (u'race', 1)
# (u'freed', 1)
# (u'fold', 1)
# (u'traveling', 1)
# (u'unavailable', 1)
# (u'vampire', 1)
# (u'overwhelmed', 1)
# (u'marketer', 1)
# (u'focuses', 1)
# (u'pushing', 1)
# (u'delivering', 1)
# (u'desired', 1)
# (u'sink', 1)
# (u'fulfill', 1)
# (u'broken', 1)
# (u'farming', 1)
# (u'opinion', 1)
# (u'maker', 1)
# (u'claim', 1)
# (u'apa', 1)
# (u'subsidizes', 1)
# (u'doubt', 1)
# (u'vehicle', 1)
# (u'average6', 1)
# (u'clever', 1)
# (u'journalists', 1)
# (u'backwards', 1)
# (u'drops', 1)
# (u'proof', 1)
# (u'distractions', 1)
# (u'lock', 1)
# (u'slim', 1)
# (u'voice', 1)
# (u'native', 1)
# (u'six', 1)
# (u'fortunate', 1)
# (u'kahneman', 1)
# (u'express', 1)
# (u'permanent', 1)
# (u'rays', 1)
# (u'workweek', 1)
# (u'owns', 1)
# (u'quantify', 1)
# (u'advocates', 1)
# (u'produces', 1)
# (u'tropics', 1)
# (u'bridges', 1)
# (u'complicate', 1)
# (u'exclusion', 1)
# (u'notebooks', 1)
# (u'laminar', 1)
# (u'faa', 1)
# (u'dhhs', 1)
# (u'spell', 1)
# (u'nurturing', 1)
# (u'applicants', 1)
# (u'worlds', 1)
# (u'undertaking', 1)
# (u'identified', 1)
# (u'magnitude', 1)
# (u'shortage', 1)
# (u'armies', 1)
# (u'parties', 1)
# (u'fraudsters', 1)
# (u'entertainment', 1)
# (u'enforceable', 1)
# (u'thriving', 1)
# (u'technically', 1)
# (u'recommendations', 1)
# (u'promptly', 1)
# (u'york', 1)
# (u'reporters', 1)
# (u'afterward', 1)
# (u'receipts', 1)
# (u'opengl', 1)
# (u'explored', 1)
# (u'binging', 1)
# (u'scare', 1)
# (u'exam', 1)
# (u'improvements', 1)
# (u'strict', 1)
# (u'312', 1)
# (u'shelf', 1)
# (u'environmental', 1)
# (u'regards', 1)
# (u'manipulation', 1)
# (u'diminish', 1)
# (u'ultimatum', 1)
# (u'culture', 1)
# (u'boring', 1)
# (u'dictate', 1)
# (u'constrained', 1)
# (u'screw', 1)
# (u'smallest', 1)
# (u'improves', 1)
# (u'embarking', 1)
# (u'telescope', 1)
# (u'issuing', 1)
# (u'tenure', 1)
# (u'outliers', 1)
# (u'lined', 1)
# (u'05', 1)
# (u'disease', 1)
# (u'enlist', 1)
# (u'graphs', 1)
# (u'godaddy', 1)
# (u'artificially', 1)
# (u'lease', 1)
# (u'interviewing', 1)
# (u'reclaiming', 1)
# (u'area5', 1)
# (u'debate', 1)
# (u'unfinished', 1)
# (u'pitfall', 1)
# (u'sued', 1)
# (u'bonds', 1)
# (u'thrived', 1)
# (u'125', 1)
# (u'assistants', 1)
# (u'h', 1)
# (u'processed', 1)
# (u'contain', 1)
# (u'conform', 1)
# (u'pitch', 1)
# (u'notifies', 1)
# (u'interacting', 1)
# (u'placed', 1)
# (u'genius', 1)
# (u'horribly', 1)
# (u'gestating', 1)
# (u'converted', 1)
# (u'routine', 1)
# (u'bought', 1)
# (u'opening', 1)
# (u'spared', 1)
# (u'approval', 1)
# (u'figured', 1)
# (u'joke', 1)
# (u'beliefs', 1)
# (u'vent', 1)
# (u'subscribe', 1)
# (u'respect', 1)
# (u'recognize', 1)
# (u'upbeat', 1)
# (u'killed', 1)
# (u'arises', 1)
# (u'releasing', 1)
# (u'ons', 1)
# (u'novel', 1)
# (u'abandoned', 1)
# (u'divorce', 1)
# (u'fault', 1)
# (u'noticed', 1)
# (u'barely', 1)
# (u'intangible', 1)
# (u'vs', 1)
# (u'optimistic', 1)
# (u'overspend', 1)
# (u'jargon', 1)
# (u'proceeds', 1)
# (u'conversations', 1)
# (u'practice', 1)
# (u'reporting', 1)
# (u'automation', 1)
# (u'variance', 1)
# (u'frequently', 1)
# (u'49', 1)
# (u'patterns', 1)
# (u'forgivable', 1)
# (u'latest', 1)
# (u'43', 1)
# (u'protecting', 1)
# (u'guts', 1)
# (u'discuss', 1)
# (u'restaurateur', 1)
# (u'attractive', 1)
# (u'garage', 1)
# (u'lends', 1)
# (u'recommendation', 1)
# (u'scares', 1)
# (u'severance', 1)
# (u'assuming', 1)
# (u'selecting', 1)
# (u'handedly', 1)
# (u'periodically', 1)
# (u'customizing', 1)
# (u'h1', 1)
# (u'tag', 1)
# (u'artists', 1)
# (u'dug', 1)
# (u'utility', 1)
# (u'suburbs', 1)
# (u'transfer', 1)
# (u'minority', 1)
# (u'indoctrinated', 1)
# (u'touted', 1)
# (u'rumsey', 1)
# (u'reminds', 1)
# (u'sba', 1)
# (u'editing', 1)
# (u'j', 1)
# (u'readership', 1)
# (u'inadequate', 1)
# (u'inc', 1)
# (u'avoided', 1)
# (u'variety', 1)
# (u'normal', 1)
# (u'welcomes', 1)
# (u'disposing', 1)
# (u'workaholic', 1)
# (u'validation', 1)
# (u'disability', 2)
# (u'blanket', 2)
# (u'vast', 2)
# (u'disciplines', 2)
# (u'weren', 2)
# (u'bonuses', 2)
# (u'reliably', 2)
# (u'reports', 2)
# (u'remnant', 2)
# (u'distributing', 2)
# (u'99', 2)
# (u'tying', 2)
# (u'join', 2)
# (u'validates', 2)
# (u'caution', 2)
# (u'attract', 2)
# (u'mess', 2)
# (u'meaningful', 2)
# (u'complexity', 2)
# (u'algorithms', 2)
# (u'fix', 2)
# (u'overcome', 2)
# (u'filling', 2)
# (u'daughters', 2)
# (u'enthusiasts', 2)
# (u'carry', 2)
# (u'lawyers', 2)
# (u'strategist', 2)
# (u'barrier', 2)
# (u'mvp', 2)
# (u'creates', 2)
# (u'california', 2)
# (u'serve', 2)
# (u'toot', 2)
# (u'incur', 2)
# (u'outlay', 2)
# (u'guilt', 2)
# (u'speaking', 2)
# (u'mostly', 2)
# (u'optimized', 2)
# (u'mouth', 2)
# (u'medical', 2)
# (u'consumer', 2)
# (u'sum', 2)
# (u'explain', 2)
# (u'bust', 2)
# (u'theme', 2)
# (u'integrate', 2)
# (u'bar', 2)
# (u'automatic', 2)
# (u'fair', 2)
# (u'alternative', 2)
# (u'artificial', 2)
# (u'modify', 2)
# (u'nudge', 2)
# (u'exceeds', 2)
# (u'puts', 2)
# (u'beneficiary', 2)
# (u'copyrights', 2)
# (u'worker', 2)
# (u'relevance', 2)
# (u'exception', 2)
# (u'tank', 2)
# (u'leaves', 2)
# (u'ii', 2)
# (u'experts', 2)
# (u'grown', 2)
# (u'thoughts', 2)
# (u'kept', 2)
# (u'hal', 2)
# (u'match', 2)
# (u'55', 2)
# (u'separately', 2)
# (u'establish', 2)
# (u'disappears', 2)
# (u'newspapers', 2)
# (u'magazine', 2)
# (u'connected', 2)
# (u'raised', 2)
# (u'wasting', 2)
# (u'magazines', 2)
# (u'wrap', 2)
# (u'resulted', 2)
# (u'head', 2)
# (u'amateur', 2)
# (u'removes', 2)
# (u'uncle', 2)
# (u'submitting', 2)
# (u'originating', 2)
# (u'proved', 2)
# (u'models', 2)
# (u'variable', 2)
# (u'attendees', 2)
# (u'precise', 2)
# (u'zone', 2)
# (u'embark', 2)
# (u'perceived', 2)
# (u'says', 2)
# (u'trend', 2)
# (u'box', 2)
# (u'commonly', 2)
# (u'bob', 2)
# (u'navigation', 2)
# (u'prefer', 2)
# (u'prey', 2)
# (u'envelope', 2)
# (u'visual', 2)
# (u'behalf', 2)
# (u'instructional', 2)
# (u'reviews', 2)
# (u'hostage', 2)
# (u'improving', 2)
# (u'explicit', 2)
# (u'tablets', 2)
# (u'subscribers', 2)
# (u'provision', 2)
# (u'bls', 2)
# (u'card', 2)
# (u'frequent', 2)
# (u'lens', 2)
# (u'seas', 2)
# (u'white', 2)
# (u'filter', 2)
# (u'friend', 2)
# (u'television', 2)
# (u'cards', 2)
# (u'gathering', 2)
# (u'federal', 2)
# (u'refining', 2)
# (u'cobra', 2)
# (u'discovered', 2)
# (u'awareness', 2)
# (u'physically', 2)
# (u'eliminating', 2)
# (u'screen', 2)
# (u'concentrated', 2)
# (u'region', 2)
# (u'duty', 2)
# (u'subscriber', 2)
# (u'hardly', 2)
# (u'direction', 2)
# (u'engineering', 2)
# (u'profiles', 2)
# (u'policies', 2)
# (u'park', 2)
# (u'food', 2)
# (u'followers', 2)
# (u'director', 2)
# (u'totally', 2)
# (u'mentally', 2)
# (u'pile', 2)
# (u'suppliers', 2)
# (u'serves', 2)
# (u'exit', 2)
# (u'considering', 2)
# (u'seconds', 2)
# (u'practical', 2)
# (u'medicare', 2)
# (u'accounts', 2)
# (u'transitioning', 2)
# (u'technologies', 2)
# (u'default', 2)
# (u'videos', 2)
# (u'endeavors', 2)
# (u'hugely', 2)
# (u'dollar', 2)
# (u'premium', 2)
# (u'horror', 2)
# (u'ticket', 2)
# (u'compounding', 2)
# (u'consumers', 2)
# (u'silverlining', 2)
# (u'geared', 2)
# (u'experimenting', 2)
# (u'rafi', 2)
# (u'shark', 2)
# (u'founders', 2)
# (u'somebody', 2)
# (u'geographical', 2)
# (u'stopped', 2)
# (u'harm', 2)
# (u'deals', 2)
# (u'offline', 2)
# (u'teach', 2)
# (u'major', 2)
# (u'fancy', 2)
# (u'construct', 2)
# (u'store', 2)
# (u'taxable', 2)
# (u'seamlessly', 2)
# (u'essentially', 2)
# (u'play', 2)
# (u'coursera', 2)
# (u'75', 2)
# (u'clean', 2)
# (u'fine', 2)
# (u'costing', 2)
# (u'dependent', 2)
# (u'feels', 2)
# (u'typos', 2)
# (u'doubled', 2)
# (u'kill', 2)
# (u'gospel', 2)
# (u'throwing', 2)
# (u'recently', 2)
# (u'improved', 2)
# (u'secrets', 2)
# (u'approve', 2)
# (u'reasons', 2)
# (u'demographic', 2)
# (u'political', 2)
# (u'adsense', 2)
# (u'meeting', 2)
# (u'unnecessarily', 2)
# (u'indefinitely', 2)
# (u'straight', 2)
# (u'behavior', 2)
# (u'anymore', 2)
# (u'powerlessness', 2)
# (u'temporary', 2)
# (u'bonus', 2)
# (u'domains', 2)
# (u'necessity', 2)
# (u'involves', 2)
# (u'grossly', 2)
# (u'advertisements', 2)
# (u'shoestring', 2)
# (u'ridiculously', 2)
# (u'emergency', 2)
# (u'niosh', 2)
# (u'aerospace', 2)
# (u'submission', 2)
# (u'ignore', 2)
# (u'describing', 2)
# (u'sections', 2)
# (u'manufacture', 2)
# (u'deductions', 2)
# (u'library', 2)
# (u'accustomed', 2)
# (u'defined', 2)
# (u'influence', 2)
# (u'inequities', 2)
# (u'occasional', 2)
# (u'leeches', 2)
# (u'helping', 2)
# (u'depicting', 2)
# (u'issues', 2)
# (u'picked', 2)
# (u'waiting', 2)
# (u'body', 2)
# (u'leveraging', 2)
# (u'explore', 2)
# (u'survivor', 2)
# (u'crazy', 2)
# (u'private', 2)
# (u'subsidies', 2)
# (u'iii', 2)
# (u'announcing', 2)
# (u'challenge', 2)
# (u'shelton', 2)
# (u'reserved', 2)
# (u'tab', 2)
# (u'invoices', 2)
# (u'pulling', 2)
# (u'employs', 2)
# (u'factored', 2)
# (u'fits', 2)
# (u'produced', 2)
# (u'chosen', 2)
# (u'2013', 2)
# (u'crash', 2)
# (u'globe', 2)
# (u'staying', 2)
# (u'ban', 2)
# (u'likelihood', 2)
# (u'organic', 2)
# (u'bid', 2)
# (u'bother', 2)
# (u'riches', 2)
# (u'lightly', 2)
# (u'reminders', 2)
# (u'imdb', 2)
# (u'accountants', 2)
# (u'bear', 2)
# (u'mohammed', 2)
# (u'dpi', 2)
# (u'capitalists', 2)
# (u'closer', 2)
# (u'precious', 2)
# (u'incubators', 2)
# (u'minds', 2)
# (u'accomplishing', 2)
# (u'trademark', 2)
# (u'devoting', 2)
# (u'adapting', 2)
# (u'moved', 2)
# (u'sufficient', 2)
# (u'spammer', 2)
# (u'orange', 2)
# (u'prescription', 2)
# (u'member', 2)
# (u'digging', 2)
# (u'underneath', 2)
# (u'increasingly', 2)
# (u'skill', 2)
# (u'increases', 2)
# (u'variants', 2)
# (u'poor', 2)
# (u'choosing', 2)
# (u'competitor', 2)
# (u'consuming', 2)
# (u'loans', 2)
# (u'rare', 2)
# (u'shipping', 2)
# (u'managing', 2)
# (u'networking', 2)
# (u'housing', 2)
# (u'apps', 2)
# (u'overestimate', 2)
# (u'biggest', 2)
# (u'universal', 2)
# (u'naming', 2)
# (u'skies', 2)
# (u'variation', 2)
# (u'chaos', 2)
# (u'preface', 2)
# (u'payoff', 2)
# (u'penny', 2)
# (u'handling', 2)
# (u'hanging', 2)
# (u'street', 2)
# (u'estimated', 2)
# (u'established', 2)
# (u'changed', 2)
# (u'slices', 2)
# (u'therefore', 2)
# (u'posting', 2)
# (u'relax', 2)
# (u'circumstances', 2)
# (u'room', 2)
# (u'guarantee', 2)
# (u'revisit', 2)
# (u'typed', 2)
# (u'loyalty', 2)
# (u'lay', 2)
# (u'bootstrap', 2)
# (u'ultimate', 2)
# (u'interpreting', 2)
# (u'devote', 2)
# (u'rankings', 2)
# (u'split', 2)
# (u'luck', 2)
# (u'independent', 2)
# (u'series', 2)
# (u'aids', 2)
# (u'adapt', 2)
# (u'wanted', 2)
# (u'tags', 2)
# (u'instagram', 2)
# (u'convention', 2)
# (u'wisdom', 2)
# (u'horn', 2)
# (u'ebay', 2)
# (u'acquire', 2)
# (u'though', 2)
# (u'visitor', 2)
# (u'advisors', 2)
# (u'solutions', 2)
# (u'sexism', 2)
# (u'situations', 2)
# (u'announce', 2)
# (u'professionals', 2)
# (u'despite', 2)
# (u'acknowledgments', 2)
# (u'decided', 2)
# (u'projections', 2)
# (u'disturbing', 2)
# (u'cut', 2)
# (u'wear', 2)
# (u'patented', 2)
# (u'refinement', 2)
# (u'gloating', 2)
# (u'101', 2)
# (u'mitigation', 2)
# (u'deeper', 2)
# (u'xxx', 2)
# (u'inertia', 2)
# (u'complex', 2)
# (u'workforce', 2)
# (u'maximizing', 2)
# (u'programs', 2)
# (u'previous', 2)
# (u'gave', 2)
# (u'apart', 2)
# (u'unnecessary', 2)
# (u'statistic', 2)
# (u'dropping', 2)
# (u'discount', 2)
# (u'census', 2)
# (u'arms', 2)
# (u'raises', 2)
# (u'editor', 2)
# (u'versions', 2)
# (u'stages', 2)
# (u'lately', 2)
# (u'escape', 2)
# (u'tie', 2)
# (u'picture', 2)
# (u'laws', 2)
# (u'whoever', 2)
# (u'polluted', 2)
# (u'governments', 2)
# (u'turns', 2)
# (u'hawaii', 2)
# (u'ries', 2)
# (u'prevent', 2)
# (u'measurable', 2)
# (u'stands', 2)
# (u'contracted', 2)
# (u'slow', 2)
# (u'wait', 2)
# (u'exams', 2)
# (u'emerge', 2)
# (u'ferriss', 2)
# (u'licensing', 2)
# (u'wealth', 2)
# (u'prove', 2)
# (u'sharing', 2)
# (u'easiest', 2)
# (u'graphic', 2)
# (u'newsletters', 2)
# (u'refine', 2)
# (u'tailor', 2)
# (u'feature', 2)
# (u'shake', 2)
# (u'possess', 2)
# (u'thankful', 2)
# (u'die', 2)
# (u'assumption', 2)
# (u'teams', 2)
# (u'tried', 2)
# (u'striking', 2)
# (u'impossible', 2)
# (u'indicate', 2)
# (u'copy', 2)
# (u'unfortunately', 2)
# (u'overcoming', 2)
# (u'printed', 2)
# (u'filing', 2)
# (u'ranking', 2)
# (u'grants', 2)
# (u'tuning', 2)
# (u'vacation', 2)
# (u'educated', 2)
# (u'external', 2)
# (u'countless', 2)
# (u'worried', 2)
# (u'author', 2)
# (u'figuring', 2)
# (u'events', 2)
# (u'finish', 2)
# (u'changing', 2)
# (u'honesty', 2)
# (u'fueling', 2)
# (u'reputable', 2)
# (u'gather', 2)
# (u'geographically', 2)
# (u'except', 2)
# (u'schedules', 2)
# (u'served', 2)
# (u'table', 2)
# (u'diving', 2)
# (u'matching', 2)
# (u'slice', 2)
# (u'provider', 2)
# (u'refer', 2)
# (u'stand', 2)
# (u'fallacy', 2)
# (u'knowledge', 2)
# (u'complete', 2)
# (u'sophisticated', 2)
# (u'nature', 2)
# (u'gone', 2)
# (u'spends', 2)
# (u'wife', 2)
# (u'scroll', 2)
# (u'forget', 2)
# (u'activities', 2)
# (u'sitting', 2)
# (u'enter', 2)
# (u'plugins', 2)
# (u'prior', 2)
# (u'specialize', 2)
# (u'cleanings', 2)
# (u'contains', 2)
# (u'particular', 2)
# (u'webmaster', 2)
# (u'science', 2)
# (u'budgets', 2)
# (u'computers', 2)
# (u'udemy', 2)
# (u'pushed', 2)
# (u'breaking', 2)
# (u'spreadsheet', 2)
# (u'doctor', 2)
# (u'suffer', 2)
# (u'smartphone', 2)
# (u'29', 2)
# (u'reuters', 2)
# (u'motivates', 2)
# (u'presented', 2)
# (u'predators', 2)
# (u'projected', 2)
# (u'pitfalls', 2)
# (u'proxy', 2)
# (u'imagine', 2)
# (u'guest', 2)
# (u'automobile', 2)
# (u'iraq', 2)
# (u'trapped', 2)
# (u'doctors', 2)
# (u'etsy', 2)
# (u'pc', 2)
# (u'headers', 2)
# (u'meanwhile', 2)
# (u'flowing', 2)
# (u'cheaper', 2)
# (u'him', 2)
# (u'appeal', 2)
# (u'activity', 2)
# (u'x', 2)
# (u'arm', 2)
# (u'definitely', 2)
# (u'representatives', 2)
# (u'relying', 2)
# (u'whom', 2)
# (u'pressed', 2)
# (u'leaning', 2)
# (u'guide', 2)
# (u'decline', 2)
# (u'hyperbole', 2)
# (u'belong', 2)
# (u'orders', 2)
# (u'recent', 2)
# (u'database', 2)
# (u'organization', 2)
# (u'desk', 2)
# (u'billable', 2)
# (u'demands', 2)
# (u'embargoed', 2)
# (u'examples', 2)
# (u'integration', 2)
# (u'behave', 2)
# (u'feelings', 2)
# (u'consultation', 2)
# (u'analyze', 2)
# (u'hobby', 2)
# (u'malicious', 2)
# (u'application', 2)
# (u'housekeepers', 2)
# (u'bankers', 2)
# (u'fresh', 2)
# (u'seemed', 2)
# (u'young', 2)
# (u'subscription', 2)
# (u'wave', 2)
# (u'tradeoffs', 2)
# (u'forbes', 2)
# (u'disclaimer', 2)
# (u'waking', 2)
# (u'consistently', 2)
# (u'experiment', 2)
# (u'3d', 2)
# (u'consideration', 2)
# (u'extreme', 2)
# (u'menu', 2)
# (u'bookkeeping', 2)
# (u'win', 2)
# (u'moonlighting', 2)
# (u'fee', 2)
# (u'women', 2)
# (u'healthcare', 2)
# (u'executives', 2)
# (u'adjust', 2)
# (u'looks', 2)
# (u'estimating', 2)
# (u'covered', 2)
# (u'auto', 2)
# (u'hands', 2)
# (u'glasses', 2)
# (u'society', 2)
# (u'integrated', 2)
# (u'clarify', 2)
# (u'determining', 2)
# (u'automating', 2)
# (u'practices', 2)
# (u'reached', 2)
# (u'precisely', 2)
# (u'realistically', 2)
# (u'shell', 2)
# (u'configure', 2)
# (u'contribute', 2)
# (u'richer', 2)
# (u'limiting', 2)
# (u'light', 2)
# (u'w2', 2)
# (u'comfortably', 2)
# (u'clearly', 2)
# (u'funds', 2)
# (u'payment', 2)
# (u'staff', 2)
# (u'partners', 2)
# (u'earned', 2)
# (u'cache', 2)
# (u'score', 2)
# (u'intentionally', 2)
# (u'calling', 2)
# (u'temporarily', 2)
# (u'responses', 2)
# (u'thank', 2)
# (u'restrictions', 2)
# (u'periodic', 2)
# (u'copies', 2)
# (u'treat', 2)
# (u'define', 2)
# (u'choices', 2)
# (u'balance', 2)
# (u'demo', 2)
# (u'politics', 2)
# (u'party', 2)
# (u'transaction', 2)
# (u'bootstrapping', 2)
# (u'executive', 2)
# (u'sources', 2)
# (u'keen', 2)
# (u'meets', 2)
# (u'increased', 2)
# (u'immediately', 2)
# (u'insert', 2)
# (u'payments', 2)
# (u'supportive', 2)
# (u'scales', 2)
# (u'helplessness', 2)
# (u'pressure', 2)
# (u'commitment', 2)
# (u'congregate', 2)
# (u'awarded', 2)
# (u'spread', 2)
# (u'bus', 2)
# (u'construction', 2)
# (u'wish', 2)
# (u'windfall', 2)
# (u'convince', 2)
# (u'pm', 2)
# (u'intimidating', 2)
# (u'meaningless', 2)
# (u'education', 2)
# (u'41', 2)
# (u'incredibly', 2)
# (u'gap', 2)
# (u'exposure', 2)
# (u'original', 2)
# (u'catch', 3)
# (u'ageism', 3)
# (u'school', 3)
# (u'estimates', 3)
# (u'hate', 3)
# (u'michal', 3)
# (u'complicated', 3)
# (u'paperwork', 3)
# (u'install', 3)
# (u'perform', 3)
# (u'worst', 3)
# (u'responsive', 3)
# (u'encounter', 3)
# (u'penetration', 3)
# (u'encourage', 3)
# (u'tempting', 3)
# (u'wasted', 3)
# (u'acquisition', 3)
# (u'radio', 3)
# (u'clicked', 3)
# (u'proposed', 3)
# (u'watch', 3)
# (u'tips', 3)
# (u'resist', 3)
# (u'depends', 3)
# (u'profitable', 3)
# (u'extend', 3)
# (u'offerings', 3)
# (u'targeting', 3)
# (u'replicate', 3)
# (u'publicly', 3)
# (u'professionally', 3)
# (u'potentially', 3)
# (u'inadvertently', 3)
# (u'steps', 3)
# (u'eye', 3)
# (u'guilty', 3)
# (u'statements', 3)
# (u'obtaining', 3)
# (u'intellectual', 3)
# (u'accordingly', 3)
# (u'talents', 3)
# (u'true', 3)
# (u'type', 3)
# (u'inside', 3)
# (u'expertise', 3)
# (u'weekend', 3)
# (u'billion', 3)
# (u'daily', 3)
# (u'alternatives', 3)
# (u'exact', 3)
# (u'minute', 3)
# (u'solves', 3)
# (u'quick', 3)
# (u'stressful', 3)
# (u'prescriptions', 3)
# (u'funded', 3)
# (u'losing', 3)
# (u'sake', 3)
# (u'council', 3)
# (u'careers', 3)
# (u'interview', 3)
# (u'resignation', 3)
# (u'beauty', 3)
# (u'possibility', 3)
# (u'trademarks', 3)
# (u'language', 3)
# (u'11', 3)
# (u'pre', 3)
# (u'note', 3)
# (u'ideal', 3)
# (u'responsibility', 3)
# (u'importantly', 3)
# (u'senior', 3)
# (u'shop', 3)
# (u'cheap', 3)
# (u'merit', 3)
# (u'resource', 3)
# (u'yield', 3)
# (u'mortgage', 3)
# (u'bureau', 3)
# (u'62', 3)
# (u'learning', 3)
# (u'constant', 3)
# (u'informed', 3)
# (u'agilesrc', 3)
# (u'incubation', 3)
# (u'covers', 3)
# (u'metric', 3)
# (u'amazed', 3)
# (u'aspect', 3)
# (u'touch', 3)
# (u'aspects', 3)
# (u'legal', 3)
# (u'generated', 3)
# (u'included', 3)
# (u'funding', 3)
# (u'aaron', 3)
# (u'shouldn', 3)
# (u'trained', 3)
# (u'conventional', 3)
# (u'charge', 3)
# (u'grabbing', 3)
# (u'sent', 3)
# (u'purchased', 3)
# (u'ego', 3)
# (u'underserved', 3)
# (u'22', 3)
# (u'button', 3)
# (u'earns', 3)
# (u'feed', 3)
# (u'behind', 3)
# (u'amass', 3)
# (u'copyright', 3)
# (u'central', 3)
# (u'publicity', 3)
# (u'sustainable', 3)
# (u'art', 3)
# (u'c', 3)
# (u'connection', 3)
# (u'empty', 3)
# (u'prices', 3)
# (u'smart', 3)
# (u'wherever', 3)
# (u'ready', 3)
# (u'twofold', 3)
# (u'moment', 3)
# (u'analysis', 3)
# (u'tablet', 3)
# (u'parents', 3)
# (u'range', 3)
# (u'extensions', 3)
# (u'primarily', 3)
# (u'peers', 3)
# (u'planet', 3)
# (u'amounts', 3)
# (u'farms', 3)
# (u'timely', 3)
# (u'augment', 3)
# (u'download', 3)
# (u'power', 3)
# (u'commercial', 3)
# (u'patents', 3)
# (u'app', 3)
# (u'decrease', 3)
# (u'obvious', 3)
# (u'hit', 3)
# (u'waters', 3)
# (u'university', 3)
# (u'cause', 3)
# (u'math', 3)
# (u'barriers', 3)
# (u'viewed', 3)
# (u'fear', 3)
# (u'approach', 3)
# (u'limit', 3)
# (u'streams', 3)
# (u'strongly', 3)
# (u'addition', 3)
# (u'unlike', 3)
# (u'harder', 3)
# (u'administration', 3)
# (u'student', 3)
# (u'ring', 3)
# (u'soft', 3)
# (u'proper', 3)
# (u'below', 3)
# (u'stories', 3)
# (u'46', 3)
# (u'virtual', 3)
# (u'kinds', 3)
# (u'portion', 3)
# (u'updates', 3)
# (u'wary', 3)
# (u'shows', 3)
# (u'surrounding', 3)
# (u'military', 3)
# (u'brings', 3)
# (u'90', 3)
# (u'rights', 3)
# (u'safe', 3)
# (u'effects', 3)
# (u'contracting', 3)
# (u'taught', 3)
# (u'restricted', 3)
# (u'millions', 3)
# (u'standard', 3)
# (u'inexpensive', 3)
# (u'levels', 3)
# (u'encouraging', 3)
# (u'clarity', 3)
# (u'listen', 3)
# (u'seen', 3)
# (u'responsibly', 3)
# (u'testing', 3)
# (u'temptation', 3)
# (u'irs', 3)
# (u'adding', 3)
# (u'improve', 3)
# (u'accident', 3)
# (u'planned', 3)
# (u'confident', 3)
# (u'property', 3)
# (u'seattle', 3)
# (u'fairly', 3)
# (u'client', 3)
# (u'night', 3)
# (u'referrals', 3)
# (u'bargain', 3)
# (u'livelihood', 3)
# (u'asking', 3)
# (u'downloading', 3)
# (u'dig', 3)
# (u'targets', 3)
# (u'headset', 3)
# (u'shared', 3)
# (u'burn', 3)
# (u'genuinely', 3)
# (u'introducing', 3)
# (u'sessions', 3)
# (u'confused', 3)
# (u'economy', 3)
# (u'truly', 3)
# (u'monitor', 3)
# (u'happened', 3)
# (u'entrepreneurship', 3)
# (u'transition', 3)
# (u'necessarily', 3)
# (u'failure', 3)
# (u'drive', 3)
# (u'outsourcing', 3)
# (u'expectation', 3)
# (u'employers', 3)
# (u'cities', 3)
# (u'workplace', 3)
# (u'former', 3)
# (u'promising', 3)
# (u'eventually', 3)
# (u'drain', 3)
# (u'commission', 3)
# (u'polish', 3)
# (u'trigger', 3)
# (u'moz', 3)
# (u'accepted', 3)
# (u'simulator', 3)
# (u'evolve', 3)
# (u'announcement', 3)
# (u'agree', 3)
# (u'measurement', 3)
# (u'field', 3)
# (u'includes', 3)
# (u'represent', 3)
# (u'titles', 3)
# (u'version', 3)
# (u'earnings', 3)
# (u'paper', 3)
# (u'27', 3)
# (u'referred', 3)
# (u'knowledgeable', 3)
# (u'connect', 3)
# (u'leverage', 3)
# (u'checklist', 3)
# (u'double', 3)
# (u'minimizing', 3)
# (u'failed', 3)
# (u'equity', 3)
# (u'achieved', 3)
# (u'currently', 3)
# (u'risks', 3)
# (u'missing', 3)
# (u'annual', 3)
# (u'likes', 3)
# (u'throughout', 3)
# (u'ensured', 3)
# (u'lived', 3)
# (u'freelancing', 3)
# (u'peoples', 3)
# (u'abilities', 3)
# (u'distracting', 3)
# (u'eliminate', 3)
# (u'regular', 3)
# (u'reputation', 3)
# (u'generates', 3)
# (u'allowing', 3)
# (u'broad', 3)
# (u'code', 3)
# (u'proposition', 3)
# (u'smaller', 3)
# (u'participate', 3)
# (u'replicated', 3)
# (u'hourly', 3)
# (u'reaching', 3)
# (u'manage', 3)
# (u'effectively', 3)
# (u'ties', 3)
# (u'2010', 3)
# (u'accompanied', 3)
# (u'interaction', 3)
# (u'crm', 3)
# (u'prospective', 3)
# (u'succeeds', 3)
# (u'offset', 3)
# (u'exactly', 3)
# (u'afraid', 3)
# (u'bedroom', 3)
# (u'plugin', 3)
# (u'walk', 3)
# (u'tread', 3)
# (u'dummies', 3)
# (u'ensuring', 3)
# (u'surprisingly', 3)
# (u'capture', 3)
# (u'compared', 3)
# (u'advertiser', 3)
# (u'announcements', 3)
# (u'sizes', 3)
# (u'platforms', 3)
# (u'literally', 3)
# (u'vesting', 3)
# (u'noise', 3)
# (u'worthy', 3)
# (u'permits', 3)
# (u'eric', 3)
# (u'corporation', 3)
# (u'detail', 3)
# (u'clicks', 3)
# (u'lasted', 3)
# (u'reliable', 4)
# (u'evaluating', 4)
# (u'china', 4)
# (u'active', 4)
# (u'changes', 4)
# (u'assessment', 4)
# (u'involve', 4)
# (u'gamble', 4)
# (u'third', 4)
# (u'fit', 4)
# (u'break', 4)
# (u'driving', 4)
# (u'tool', 4)
# (u'showed', 4)
# (u'forces', 4)
# (u'competitors', 4)
# (u'pocket', 4)
# (u'report', 4)
# (u'faced', 4)
# (u'protect', 4)
# (u'expected', 4)
# (u'couple', 4)
# (u'hang', 4)
# (u'objective', 4)
# (u'plus', 4)
# (u'belongings', 4)
# (u'becoming', 4)
# (u'premiums', 4)
# (u'push', 4)
# (u'managed', 4)
# (u'posts', 4)
# (u'compare', 4)
# (u'flexibility', 4)
# (u'clicking', 4)
# (u'dedicated', 4)
# (u'cold', 4)
# (u'saw', 4)
# (u'conversion', 4)
# (u'efficient', 4)
# (u'channel', 4)
# (u'steady', 4)
# (u'contracts', 4)
# (u'offered', 4)
# (u'trick', 4)
# (u'motivated', 4)
# (u'rules', 4)
# (u'detailed', 4)
# (u'together', 4)
# (u'pool', 4)
# (u'calls', 4)
# (u'issue', 4)
# (u'study', 4)
# (u'design', 4)
# (u'contrast', 4)
# (u'followed', 4)
# (u'armed', 4)
# (u'producing', 4)
# (u'rather', 4)
# (u'american', 4)
# (u'trouble', 4)
# (u'style', 4)
# (u'letting', 4)
# (u'guess', 4)
# (u'experiences', 4)
# (u'extremely', 4)
# (u'salary', 4)
# (u'clear', 4)
# (u'impact', 4)
# (u'access', 4)
# (u'keyword', 4)
# (u'sold', 4)
# (u'license', 4)
# (u'worthless', 4)
# (u'maintenance', 4)
# (u'convert', 4)
# (u'widely', 4)
# (u'moving', 4)
# (u'weird', 4)
# (u'competitive', 4)
# (u'love', 4)
# (u'startups', 4)
# (u'discipline', 4)
# (u'showing', 4)
# (u'projects', 4)
# (u'forward', 4)
# (u'visits', 4)
# (u'ago', 4)
# (u'independently', 4)
# (u'depth', 4)
# (u'putting', 4)
# (u'notes', 4)
# (u'degree', 4)
# (u'actual', 4)
# (u'closing', 4)
# (u'specifications', 4)
# (u'requirements', 4)
# (u'mentioned', 4)
# (u'industries', 4)
# (u'2015', 4)
# (u'2011', 4)
# (u'afford', 4)
# (u'relations', 4)
# (u'collecting', 4)
# (u'discussions', 4)
# (u'worldwide', 4)
# (u'acquired', 4)
# (u'signed', 4)
# (u'co', 4)
# (u'prospects', 4)
# (u'present', 4)
# (u'40', 4)
# (u'sky', 4)
# (u'simple', 4)
# (u'execute', 4)
# (u'authority', 4)
# (u'lead', 4)
# (u'leap', 4)
# (u'searches', 4)
# (u'count', 4)
# (u'places', 4)
# (u'minutes', 4)
# (u'shown', 4)
# (u'oceans', 4)
# (u'designing', 4)
# (u'replace', 4)
# (u'survive', 4)
# (u'aware', 4)
# (u'keeps', 4)
# (u'modern', 4)
# (u'tells', 4)
# (u'responsible', 4)
# (u'involving', 4)
# (u'busy', 4)
# (u'unemployment', 4)
# (u'readers', 4)
# (u'gotten', 4)
# (u'trust', 4)
# (u'speak', 4)
# (u'basis', 4)
# (u'craft', 4)
# (u'format', 4)
# (u'pick', 4)
# (u'narrow', 4)
# (u'financially', 4)
# (u'manufacturing', 4)
# (u'pays', 4)
# (u'update', 4)
# (u'team', 4)
# (u'trial', 4)
# (u'fake', 4)
# (u'optimize', 4)
# (u'produce', 4)
# (u'platform', 4)
# (u'views', 4)
# (u'drop', 4)
# (u'quarter', 4)
# (u'significantly', 4)
# (u'gaming', 4)
# (u'accomplish', 4)
# (u'engineer', 4)
# (u'remotely', 4)
# (u'wide', 4)
# (u'title', 4)
# (u'morning', 4)
# (u'article', 4)
# (u'among', 4)
# (u'wisely', 4)
# (u'drives', 4)
# (u'identifying', 4)
# (u'provided', 4)
# (u'felt', 4)
# (u'exciting', 4)
# (u'throw', 4)
# (u'quickbooks', 4)
# (u'difference', 4)
# (u'gov', 4)
# (u'public', 4)
# (u'strong', 4)
# (u'fired', 4)
# (u'options', 4)
# (u'specializes', 4)
# (u'challenging', 4)
# (u'adventure', 4)
# (u'response', 4)
# (u'developed', 4)
# (u'solving', 4)
# (u'systems', 4)
# (u'courses', 4)
# (u'mental', 4)
# (u'mailchimp', 4)
# (u'definition', 4)
# (u'leading', 4)
# (u'supposed', 4)
# (u'alongside', 4)
# (u'built', 4)
# (u'majority', 4)
# ...
# (u'positive', 5)
# (u'avoiding', 5)
# (u'oculus', 5)
# (u'interesting', 5)
# (u'mail', 5)
# (u'lunch', 5)
# (u'space', 5)
# (u'quite', 5)
# (u'honest', 5)
# (u'2', 5)
# (u'articles', 5)
# (u'gives', 5)
# (u'simulators', 5)
# (u'impressions', 5)
# (u'worthwhile', 5)
# (u'prototype', 5)
# (u'locally', 5)
# (u'agreements', 5)
# (u'attainable', 5)
# (u'fill', 5)
# (u'ideally', 5)
# (u'lack', 5)
# (u'program', 5)
# (u'worse', 5)
# (u'tracking', 5)
# (u'6', 5)
# (u'knows', 5)
# (u'paragraph', 5)
# (u'numbers', 5)
# (u'developer', 5)
# (u'wouldn', 5)
# (u'fees', 5)
# (u'hundred', 5)
# (u'discover', 5)
# (u'risky', 5)
# (u'english', 5)
# (u'his', 5)
# (u'competing', 5)
# (u'raise', 5)
# (u'task', 5)
# (u'economic', 5)
# (u'referrer', 5)
# (u'simulation', 5)
# (u'prepared', 5)
# (u'capital', 5)
# (u'factor', 5)
# (u'united', 5)
# (u'communication', 5)
# (u'our', 5)
# (u'conversation', 5)
# (u'publication', 5)
# (u'visited', 5)
# (u'lucky', 5)
# (u'areas', 5)
# (u'fixed', 5)
# (u'otherwise', 5)
# (u'earning', 5)
# (u'waste', 5)
# (u'received', 5)
# (u'obtain', 5)
# (u'schedule', 5)
# (u'details', 5)
# (u'saved', 6)
# (u'reasonable', 6)
# (u'messages', 6)
# (u'sound', 6)
# (u'fail', 6)
# (u'sorts', 6)
# (u'qualities', 6)
# (u'advertise', 6)
# (u'comments', 6)
# (u'rely', 6)
# (u'considered', 6)
# (u'commuting', 6)
# (u'assume', 6)
# (u'llc', 6)
# (u'certainly', 6)
# (u'depend', 6)
# (u'finally', 6)
# (u'keeping', 6)
# (u'liability', 6)
# (u'shares', 6)
# (u'goes', 6)
# (u'forms', 6)
# (u'connections', 6)
# (u'vision', 6)
# (u'exist', 6)
# (u'contract', 6)
# (u'solve', 6)
# (u'benefit', 6)
# (u'determine', 6)
# (u'founder', 6)
# (u'tv', 6)
# (u'past', 6)
# (u'ahead', 6)
# (u'automate', 6)
# (u'markets', 6)
# (u'silicon', 6)
# (u'story', 6)
# (u'kind', 6)
# (u'rest', 6)
# (u'flight', 6)
# (u'fire', 6)
# (u'unlimited', 6)
# (u'lost', 6)
# (u'line', 6)
# (u'associated', 6)
# (u'globally', 6)
# (u'structure', 6)
# (u'remarketing', 6)
# (u'resulting', 6)
# (u'control', 6)
# (u'allow', 6)
# (u'url', 6)
# (u'handle', 6)
# (u'initially', 6)
# (u'key', 6)
# (u'wall', 6)
# (u'distribution', 6)
# (u'told', 6)
# (u'met', 6)
# (u'items', 6)
# (u'mine', 6)
# (u'manner', 6)
# (u'forced', 6)
# (u'effectiveness', 6)
# (u'techniques', 6)
# (u'country', 6)
# (u'basic', 6)
# (u'board', 6)
# (u'somehow', 6)
# (u'sale', 6)
# (u'stick', 6)
# (u'concept', 6)
# (u'choice', 6)
# (u'talked', 6)
# (u'sending', 6)
# (u'rarely', 6)
# (u'entrepreneurs', 6)
# (u'productive', 6)
# (u'designer', 6)
# (u'main', 6)
# (u'million', 6)
# (u'dependencies', 6)
# (u'rent', 6)
# (u'knew', 6)
# (u'especially', 6)
# (u'careful', 6)
# (u'largely', 6)
# (u'reward', 6)
# (u'package', 6)
# (u'mean', 6)
# (u'stake', 6)
# (u'separate', 6)
# (u'base', 6)
# (u'seeking', 6)
# (u'experienced', 6)
# (u'sole', 6)
# (u'became', 6)
# (u'due', 6)
# (u'collect', 6)
# (u'properly', 6)
# (u'choose', 6)
# (u'scary', 6)
# (u'booth', 6)
# (u'providing', 6)
# (u'comfortable', 6)
# (u'users', 6)
# (u'etc', 6)
# (u'deductible', 6)
# (u'partner', 6)
# (u'works', 6)
# (u'hosting', 6)
# (u'completely', 7)
# (u'crucial', 7)
# (u'meetings', 7)
# (u'lots', 7)
# (u'games', 7)
# (u'ownership', 7)
# (u'orlando', 7)
# (u'dental', 7)
# (u'wordpress', 7)
# (u'generally', 7)
# (u'leads', 7)
# (u'groups', 7)
# (u'someplace', 7)
# (u'open', 7)
# (u'track', 7)
# (u'images', 7)
# (u'standpoint', 7)
# (u'ok', 7)
# (u'wants', 7)
# (u'safety', 7)
# (u'salesperson', 7)
# (u'taken', 7)
# (u'energy', 7)
# (u'reason', 7)
# (u'zero', 7)
# (u'carefully', 7)
# (u'workers', 7)
# (u'flow', 7)
# (u'single', 7)
# (u'requires', 7)
# (u'video', 7)
# (u'interests', 7)
# (u'bet', 7)
# (u'thousands', 7)
# (u'upon', 7)
# (u'maintaining', 7)
# (u'engines', 7)
# (u'marketplace', 7)
# (u'protection', 7)
# (u'kids', 7)
# (u'description', 7)
# (u'save', 7)
# (u'mistake', 7)
# (u'presence', 7)
# (u'freelancer', 7)
# (u'setting', 7)
# (u'describe', 7)
# (u'continue', 7)
# (u'heard', 7)
# (u'designed', 7)
# (u'half', 7)
# (u'earlier', 7)
# (u'turn', 7)
# (u'dedicate', 7)
# (u'period', 7)
# (u'valley', 7)
# (u'certain', 7)
# (u'general', 7)
# (u'follow', 7)
# (u'further', 7)
# (u'trade', 7)
# (u'everyone', 7)
# (u'spouse', 7)
# (u'appear', 7)
# (u'8', 7)
# (u'defense', 7)
# (u'strategy', 7)
# (u'fund', 7)
# (u'location', 7)
# (u'sdk', 7)
# (u'leaving', 7)
# (u'addresses', 7)
# (u'bunch', 7)
# (u'mention', 7)
# (u'books', 7)
# (u'upper', 7)
# (u'view', 7)
# (u'difficult', 7)
# (u'additional', 7)
# (u'stay', 7)
# (u'bank', 8)
# (u'message', 8)
# (u'top', 8)
# (u'lpo', 8)
# (u'rich', 8)
# (u'identify', 8)
# (u'security', 8)
# (u'www', 8)
# (u'old', 8)
# (u'form', 8)
# (u'leave', 8)
# (u'visit', 8)
# (u'write', 8)
# (u'anyone', 8)
# (u'venture', 8)
# (u'notice', 8)
# (u'useful', 8)
# (u'worry', 8)
# (u'develop', 8)
# (u'opportunities', 8)
# (u'triton', 8)
# (u'taxes', 8)
# (u'add', 8)
# (u'checking', 8)
# (u'lean', 8)
# (u'under', 8)
# (u'credit', 8)
# (u'feedback', 8)
# (u'user', 8)
# (u'took', 8)
# (u'three', 8)
# (u'several', 8)
# (u'left', 8)
# (u'successfully', 8)
# (u'editors', 8)
# (u'understanding', 8)
# (u'tasks', 8)
# (u'city', 8)
# (u'soon', 8)
# (u'evaluate', 8)
# (u'easily', 8)
# (u'beyond', 8)
# (u'common', 8)
# (u'mission', 8)
# (u'higher', 8)
# (u'matters', 8)
# (u'agreement', 8)
# (u'car', 8)
# (u'reserves', 8)
# (u'2012', 8)
# (u'haven', 8)
# (u'computer', 8)
# (u'tend', 8)
# (u'2014', 8)
# (u'gets', 8)
# (u'stage', 8)
# (u'answer', 9)
# (u'tech', 9)
# (u'amazon', 9)
# (u'savings', 9)
# (u'deal', 9)
# (u'manager', 9)
# (u'alone', 9)
# (u'following', 9)
# (u'stream', 9)
# (u'increase', 9)
# (u'ultimately', 9)
# (u'college', 9)
# (u'hear', 9)
# (u'measuring', 9)
# (u'rate', 9)
# (u'share', 9)
# (u'accept', 9)
# (u'ceo', 9)
# (u'relationship', 9)
# (u'mobile', 9)
# (u'loan', 9)
# (u'simply', 9)
# (u'bit', 9)
# (u'twitter', 9)
# (u'quality', 9)
# (u'purchasing', 9)
# (u'achieve', 9)
# (u'maximize', 9)
# (u'http', 9)
# (u'happens', 9)
# (u'affect', 9)
# (u'phone', 9)
# (u'times', 9)
# (u'easier', 9)
# (u'created', 9)
# (u'said', 9)
# (u'boss', 9)
# (u'creative', 9)
# (u'viable', 9)
# (u'cannot', 9)
# (u'reading', 9)
# (u'across', 9)
# (u'4', 9)
# (u'fraud', 9)
# (u'minimum', 9)
# (u'house', 9)
# (u'option', 9)
# (u'sometimes', 9)
# (u'demand', 9)
# (u'goods', 9)
# (u'called', 9)
# (u'involved', 9)
# (u'apply', 9)
# (u'clients', 9)
# (u'meet', 9)
# (u'stock', 9)
# (u'system', 9)
# (u'text', 9)
# (u'position', 9)
# (u'government', 9)
# (u'he', 9)
# (u'ever', 10)
# (u'100', 10)
# (u'employees', 10)
# (u'given', 10)
# (u'percentage', 10)
# (u'last', 10)
# (u'along', 10)
# (u'domain', 10)
# (u'training', 10)
# (u'promotion', 10)
# (u'investors', 10)
# (u'jobs', 10)
# (u'thinking', 10)
# (u'blog', 10)
# (u'odds', 10)
# (u'starting', 10)
# (u'beware', 10)
# (u'known', 10)
# (u'traditional', 10)
# (u'banner', 10)
# (u'expensive', 10)
# (u'pr', 10)
# (u'monthly', 10)
# (u'receive', 10)
# (u'popular', 10)
# (u'question', 10)
# (u'mailing', 10)
# (u'process', 10)
# (u'stop', 10)
# (u'related', 10)
# (u'anyhow', 10)
# (u'employee', 10)
# (u'deliver', 10)
# (u'necessary', 10)
# (u'although', 10)
# (u'friends', 10)
# (u'maintain', 10)
# (u'talking', 10)
# (u'hopefully', 10)
# (u'expense', 10)
# (u'unique', 10)
# (u'level', 10)
# (u'according', 10)
# (u'kane', 10)
# (u'performance', 10)
# (u'quitting', 10)
# (u'ended', 10)
# (u'since', 10)
# (u'takes', 10)
# (u'plans', 10)
# (u'short', 10)
# (u'depending', 10)
# (u'exchange', 10)
# (u'names', 10)
# (u'purposes', 10)
# (u'individual', 10)
# (u'course', 10)
# (u'lose', 10)
# (u'call', 11)
# (u'service', 11)
# (u'seem', 11)
# (u'came', 11)
# (u'patent', 11)
# (u'launching', 11)
# (u'test', 11)
# (u'today', 11)
# (u'directly', 11)
# (u'average', 11)
# (u'technology', 11)
# (u'running', 11)
# (u'early', 11)
# (u'section', 11)
# (u'learned', 11)
# (u'startup', 11)
# (u'9', 11)
# (u'technical', 11)
# (u'high', 11)
# (u'responsibilities', 11)
# (u'front', 11)
# (u'linkedin', 11)
# (u'paycheck', 11)
# (u'recommend', 11)
# (u'cpa', 11)
# (u'size', 11)
# (u'rewards', 11)
# (u'countries', 11)
# (u'ocean', 11)
# (u'bound', 11)
# (u'accounting', 11)
# (u'reality', 11)
# (u'digital', 11)
# (u'visitors', 11)
# (u'between', 11)
# (u'situation', 11)
# (u'interested', 11)
# (u'act', 11)
# (u'expect', 11)
# (u'invest', 11)
# (u'basically', 11)
# (u'research', 11)
# (u'during', 11)
# (u'close', 11)
# (u'contractor', 11)
# (u'statistics', 11)
# (u'highly', 11)
# (u'larger', 11)
# (u'publications', 11)
# (u'willing', 11)
# (u'bills', 11)
# (u'include', 11)
# (u'frank', 11)
# (u'goals', 11)
# (u'searching', 11)
# (u'channels', 12)
# (u'against', 12)
# (u'opportunity', 12)
# (u'advantage', 12)
# (u'stress', 12)
# (u'experience', 12)
# (u'comes', 12)
# (u'valuable', 12)
# (u'am', 12)
# (u'licenses', 12)
# (u'cover', 12)
# (u'community', 12)
# (u'decision', 12)
# (u'link', 12)
# (u'resources', 12)
# (u'growing', 12)
# (u'makes', 12)
# (u'links', 12)
# (u'almost', 12)
# (u'chance', 12)
# (u'limited', 12)
# (u'basics', 12)
# (u'budget', 12)
# (u'network', 12)
# (u'needed', 12)
# (u'target', 12)
# (u'emails', 12)
# (u'everything', 12)
# (u'realistic', 12)
# (u'equipment', 12)
# (u'freelancers', 12)
# (u'sense', 12)
# (u'scale', 12)
# (u'move', 12)
# (u'automated', 12)
# (u'looking', 13)
# (u'enjoy', 13)
# (u'net', 13)
# (u'tied', 13)
# (u'lower', 13)
# (u'bad', 13)
# (u'interest', 13)
# (u'support', 13)
# (u'ensure', 13)
# (u'happen', 13)
# (u'price', 13)
# (u'3', 13)
# (u'engine', 13)
# (u'myself', 13)
# (u'ongoing', 13)
# (u'5', 13)
# (u'coverage', 13)
# (u'put', 13)
# (u'owners', 13)
# (u'questions', 13)
# (u'game', 13)
# (u'send', 13)
# (u'1', 13)
# (u'unless', 13)
# (u'avoid', 13)
# (u'personally', 13)
# (u'direct', 13)
# (u'purchase', 13)
# (u'days', 13)
# (u'matter', 13)
# (u'yet', 13)
# (u'huge', 13)
# (u'longer', 13)
# (u'toward', 13)
# (u'itself', 13)
# (u'made', 13)
# (u'estimate', 14)
# (u'automatically', 14)
# (u'effective', 14)
# (u'require', 14)
# (u'outside', 14)
# (u'targeted', 14)
# (u'read', 14)
# (u'trends', 14)
# (u'figure', 14)
# (u'fact', 14)
# (u'news', 14)
# (u'face', 14)
# (u'realize', 14)
# (u'address', 14)
# (u'pages', 14)
# (u'either', 14)
# (u'commute', 14)
# (u'both', 14)
# (u'tell', 14)
# (u'required', 14)
# (u'management', 14)
# (u'stuff', 14)
# (u'become', 14)
# (u'far', 15)
# (u'return', 15)
# (u'keywords', 15)
# (u'freelance', 15)
# (u'entirely', 15)
# (u'reach', 15)
# (u'nothing', 15)
# (u'seo', 15)
# (u'problems', 15)
# (u'writing', 15)
# (u'future', 15)
# (u'quickly', 15)
# (u'yours', 15)
# (u'happy', 15)
# (u'check', 15)
# (u'low', 15)
# (u'optimization', 15)
# (u'entire', 15)
# (u'ability', 15)
# (u'didn', 15)
# (u'buy', 15)
# (u'earn', 16)
# (u'worked', 16)
# (u'did', 16)
# (u'releases', 16)
# (u'offering', 16)
# (u'investing', 16)
# (u'giving', 16)
# (u'themselves', 16)
# (u'state', 16)
# (u'until', 16)
# (u'contact', 16)
# (u'analytics', 16)
# (u'50', 16)
# (u'professional', 16)
# (u'area', 16)
# (u'generate', 16)
# (u'believe', 16)
# (u'creating', 16)
# (u'networks', 16)
# (u'next', 16)
# (u'planning', 16)
# (u'offers', 16)
# (u'skills', 17)
# (u'wrong', 17)
# (u'financial', 17)
# (u'content', 17)
# (u'mind', 17)
# (u'corporate', 17)
# (u'efforts', 17)
# (u'profit', 17)
# (u'lawyer', 17)
# (u'amount', 17)
# (u'finding', 17)
# (u'spending', 17)
# (u'owner', 17)
# (u'hiring', 17)
# (u'two', 17)
# (u'coming', 17)
# (u'existing', 17)
# (u'change', 18)
# (u'pretty', 18)
# (u'started', 18)
# (u'value', 18)
# (u'risk', 18)
# (u'each', 18)
# (u'developers', 18)
# (u'sites', 18)
# (u'media', 18)
# (u'month', 18)
# (u'used', 18)
# (u'd', 18)
# (u'within', 18)
# (u'display', 18)
# (u'development', 19)
# (u'away', 19)
# (u'com', 19)
# (u'landing', 19)
# (u'current', 19)
# (u'ways', 19)
# (u'industry', 19)
# (u'decide', 19)
# (u'hour', 19)
# (u'doesn', 19)
# (u'great', 19)
# (u'based', 19)
# (u'taking', 19)
# (u'accountant', 19)
# (u'path', 19)
# (u'nobody', 19)
# (u'physical', 19)
# (u'maybe', 19)
# (u'show', 19)
# (u'cash', 19)
# (u'again', 19)
# (u'investment', 19)
# (u'goal', 19)
# (u'always', 19)
# (u'person', 19)
# (u'niche', 20)
# (u'terms', 20)
# (u'usually', 20)
# (u'dollars', 20)
# (u'term', 20)
# (u'aren', 20)
# (u'facebook', 20)
# (u'ask', 20)
# (u'benefits', 20)
# (u'services', 20)
# (u'sort', 20)
# (u'hire', 20)
# (u'example', 20)
# (u'around', 20)
# (u'contractors', 20)
# (u'ones', 20)
# (u'attention', 20)
# (u'campaign', 21)
# (u'down', 21)
# (u'available', 21)
# (u'place', 21)
# (u'different', 21)
# (u'action', 21)
# (u'whether', 21)
# (u'costs', 21)
# (u'grow', 21)
# (u'developing', 21)
# (u'spent', 21)
# (u'click', 21)
# (u'quit', 21)
# (u'list', 22)
# (u'paying', 22)
# (u'able', 22)
# (u'problem', 22)
# (u'later', 22)
# (u'focus', 22)
# (u'learn', 22)
# (u'extra', 22)
# (u'name', 22)
# (u'found', 22)
# (u'campaigns', 23)
# (u'metrics', 23)
# (u'say', 23)
# (u'paid', 23)
# (u'feel', 23)
# (u'anything', 23)
# (u'us', 23)
# (u'off', 23)
# (u'already', 23)
# (u'months', 23)
# (u'remember', 23)
# (u'10', 23)
# (u'got', 23)
# (u'provide', 24)
# (u'data', 24)
# (u'sundog', 24)
# (u'needs', 24)
# (u'success', 24)
# (u'right', 24)
# (u'care', 24)
# (u'world', 24)
# (u'insurance', 24)
# (u'launch', 24)
# (u'build', 24)
# (u'result', 24)
# (u'000', 24)
# (u'income', 24)
# (u'been', 25)
# (u'live', 25)
# (u'week', 25)
# (u'why', 25)
# (u'making', 25)
# (u'information', 25)
# (u'using', 25)
# (u'results', 25)
# (u'trying', 25)
# (u'less', 25)
# (u'another', 26)
# (u'effort', 26)
# (u'case', 26)
# (u'family', 26)
# (u'likely', 26)
# (u'perhaps', 26)
# (u'whatever', 26)
# (u'internet', 26)
# (u'consider', 26)
# (u'set', 26)
# (u'often', 26)
# (u'successful', 27)
# (u'run', 27)
# (u'similar', 27)
# (u'never', 27)
# (u'isn', 27)
# (u'ideas', 27)
# (u'initial', 27)
# (u'living', 27)
# (u'full', 27)
# (u'measure', 27)
# (u'relevant', 27)
# (u'home', 27)
# (u'___', 28)
# (u'done', 28)
# (u'too', 28)
# (u'look', 28)
# (u'because', 28)
# (u'here', 29)
# (u'office', 29)
# (u'had', 29)
# (u'little', 29)
# (u'same', 29)
# (u'tax', 29)
# (u'thing', 29)
# (u'must', 29)
# (u'offer', 29)
# (u'm', 30)
# (u'come', 30)
# (u'large', 30)
# (u'account', 30)
# (u'side', 30)
# (u'possible', 30)
# (u'having', 30)
# (u'means', 30)
# (u'adwords', 30)
# (u'does', 30)
# (u'companies', 31)
# (u'life', 31)
# (u'real', 31)
# (u'websites', 31)
# (u'least', 31)
# (u'sell', 31)
# (u'career', 31)
# (u'give', 31)
# (u'getting', 31)
# (u'every', 32)
# (u'release', 32)
# (u'easy', 32)
# (u'talk', 32)
# (u'being', 32)
# (u'let', 32)
# (u'order', 32)
# (u'actually', 32)
# (u'traffic', 33)
# (u'building', 33)
# (u'after', 33)
# (u'selling', 33)
# (u'part', 33)
# (u'else', 33)
# (u'email', 33)
# (u'me', 34)
# (u'per', 34)
# (u'back', 34)
# (u'free', 35)
# (u'specific', 35)
# (u'understand', 35)
# (u'hours', 35)
# (u'health', 35)
# (u'web', 35)
# (u'would', 36)
# (u'however', 36)
# (u'social', 36)
# (u'its', 36)
# (u'which', 37)
# (u'others', 37)
# (u'point', 37)
# (u'instead', 37)
# (u'expenses', 38)
# (u'things', 38)
# (u'potential', 38)
# (u'site', 38)
# (u'employed', 38)
# (u'years', 38)
# (u'local', 39)
# (u'worth', 39)
# (u'were', 39)
# (u'book', 39)
# (u'won', 39)
# (u'growth', 39)
# (u'has', 40)
# (u'without', 40)
# (u'few', 40)
# (u'customer', 41)
# (u'advertising', 41)
# (u'number', 41)
# (u'freedom', 41)
# (u'marketing', 42)
# (u'really', 42)
# (u'big', 42)
# (u'keep', 42)
# (u'page', 42)
# (u'while', 43)
# (u'we', 43)
# (u'press', 43)
# (u'such', 43)
# (u'spend', 43)
# (u'best', 44)
# (u'lifestyle', 44)
# (u'advice', 44)
# (u'revenue', 44)
# (u'start', 44)
# (u'employer', 44)
# (u'create', 45)
# (u'go', 45)
# (u'pay', 45)
# (u'could', 46)
# (u'small', 47)
# (u'businesses', 47)
# (u'long', 47)
# (u'try', 47)
# (u'hard', 47)
# (u'personal', 48)
# (u'see', 48)
# (u'now', 48)
# (u'end', 49)
# (u'better', 49)
# (u'year', 49)
# (u'online', 50)
# (u'help', 50)
# (u'doing', 51)
# (u'first', 51)
# (u'know', 52)
# (u'where', 53)
# (u'cost', 53)
# (u'way', 55)
# (u'lot', 55)
# (u'take', 55)
# (u'going', 55)
# (u'search', 56)
# (u'something', 56)
# (u'through', 57)
# (u'working', 58)
# (u'very', 58)
# (u'use', 58)
# (u'think', 58)
# (u'important', 58)
# (u'enough', 59)
# (u'then', 59)
# (u'once', 59)
# (u'idea', 60)
# (u'software', 60)
# (u'over', 62)
# (u'any', 62)
# (u'someone', 62)
# (u'google', 63)
# (u'plan', 64)
# (u'still', 65)
# (u'sure', 65)
# (u'market', 66)
# (u'well', 66)
# (u'products', 67)
# (u'those', 68)
# (u'should', 69)
# (u'might', 70)
# (u'before', 70)
# (u'ad', 70)
# (u'most', 70)
# (u'many', 71)
# (u'good', 72)
# (u'day', 73)
# (u'employment', 75)
# (u'ads', 75)
# (u'no', 76)
# (u'probably', 76)
# (u'yourself', 78)
# (u'like', 78)
# (u'other', 78)
# (u'only', 79)
# (u'into', 79)
# (u'sales', 80)
# (u'find', 81)
# (u'these', 82)
# (u'was', 85)
# (u'money', 86)
# (u'who', 88)
# (u'job', 90)
# (u'much', 90)
# (u'also', 91)
# (u'than', 92)
# (u've', 95)
# (u'one', 100)
# (u'when', 102)
# (u'even', 104)
# (u'may', 107)
# (u'make', 108)
# (u'website', 109)
# (u'self', 111)
# (u'll', 114)
# (u'some', 121)
# (u'want', 122)
# (u'company', 122)
# (u'by', 122)
# (u'their', 122)
# (u'customers', 123)
# (u'get', 123)
# (u'don', 133)
# (u'all', 137)
# (u'own', 140)
# (u'just', 142)
# (u'so', 143)
# (u'work', 144)
# (u'people', 145)
# (u'new', 153)
# (u'out', 161)
# (u'there', 162)
# (u'how', 163)
# (u'them', 166)
# (u'from', 166)
# (u'need', 174)
# (u'up', 177)
# (u'an', 178)
# (u'product', 182)
# (u'more', 200)
# (u'about', 202)
# (u'not', 203)
# (u'do', 207)
# (u're', 214)
# (u'my', 215)
# (u'at', 220)
# (u'what', 229)
# (u'will', 231)
# (u'they', 234)
# (u'but', 242)
# (u'time', 255)
# (u'or', 278)
# (u'this', 280)
# (u't', 301)
# (u'with', 315)
# (u'have', 321)
# (u'as', 343)
# (u'be', 369)
# (u'can', 376)
# (u'business', 383)
# (u'i', 387)
# (u's', 391)
# (u'if', 411)
# (u'are', 424)
# (u'on', 428)
# (u'for', 537)
# (u'is', 560)
# (u'in', 616)
# (u'it', 649)
# (u'that', 747)
# (u'', 772)
# (u'and', 934)
# (u'of', 970)
# (u'a', 1191)
# (u'the', 1292)
# (u'your', 1420)
# (u'to', 1828)
# (u'you', 1878)

# %%
sc.stop()
